# %% [markdown]
# <a href="https://colab.research.google.com/github/karinboc/Recommenders/blob/main/Evaluation4_caser_artlist_ver3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Microsoft Caser**
# Algorithm based on convolutions that aim to capture both user’s general preferences and sequential patterns

# %% [markdown]
# ###Env setting

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !git clone https://github.com/Microsoft/Recommenders

# %cd Recommenders
# !python tools/generate_conda_file.py
#!conda env create -f reco_base.yaml
# Out:
# Cloning into 'Recommenders'...
# remote: Enumerating objects: 25696, done.
# remote: Counting objects: 100% (585/585), done.
# remote: Compressing objects: 100% (377/377), done.
# remote: Total 25696 (delta 331), reused 388 (delta 205), pack-reused 25111
# Receiving objects: 100% (25696/25696), 198.67 MiB | 27.66 MiB/s, done.
# Resolving deltas: 100% (16804/16804), done.
# /content/Recommenders
# Generated conda file: reco_base.yaml
#
# To create the conda environment:
# $ conda env create -f reco_base.yaml
#
# To update the conda environment:
# $ conda env update -f reco_base.yaml
#
# To register the conda environment in Jupyter:
# $ conda activate reco_base
# $ python -m ipykernel install --user --name reco_base --display-name "Python (reco_base)"

# %%
# !ls reco_utils/recommender/deeprec/config
# Out:
# asvd.yaml   gru4rec.yaml   nextitnet.yaml  sum.yaml
# caser.yaml  lightgcn.yaml  sli_rec.yaml

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# try to run the bare minimum to get a new conda env working
conda_path = ''
try:
    conda_path = !which conda
finally:
    print('')

if (len(conda_path) == 0):
    print('installing miniconda')
    # !wget https://repo.continuum.io/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh && bash Miniconda3-4.5.4-Linux-x86_64.sh -bfp /usr/local
    # !conda update conda -y -q
    # !source /usr/local/etc/profile.d/conda.sh
    # !conda init 
    # !conda install -n root _license -y -q
else:
    print('found miniconda')
# Out:
# installing miniconda
# --2021-05-22 07:36:57--  https://repo.continuum.io/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh [following]
# --2021-05-22 07:36:57--  https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58468498 (56M) [application/x-sh]
# Saving to: ‘Miniconda3-4.5.4-Linux-x86_64.sh’
#
# Miniconda3-4.5.4-Li 100%[===================>]  55.76M   142MB/s    in 0.4s
#
# 2021-05-22 07:36:58 (142 MB/s) - ‘Miniconda3-4.5.4-Linux-x86_64.sh’ saved [58468498/58468498]
#
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# Python 3.6.5 :: Anaconda, Inc.
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# installing: ruamel_yaml-0.15.37-py36h14c3975_2 ...
# installing: six-1.11.0-py36h372c433_1 ...
# installing: cffi-1.11.5-py36h9745a5d_0 ...
# installing: setuptools-39.2.0-py36_0 ...
# installing: cryptography-2.2.2-py36h14c3975_0 ...
# installing: wheel-0.31.1-py36_0 ...
# installing: pip-10.0.1-py36_0 ...
# installing: pyopenssl-18.0.0-py36_0 ...
# installing: urllib3-1.22-py36hbe7ace6_0 ...
# installing: requests-2.18.4-py36he2e5f8d_1 ...
# installing: conda-4.5.4-py36_0 ...
# installation finished.
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     zlib-1.2.11                |       h7b6447c_3         120 KB
#     yaml-0.2.5                 |       h7b6447c_0          87 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     cryptography-2.3.1         |   py37hc365091_0         585 KB
#     pycparser-2.20             |             py_2          94 KB
#     wheel-0.36.2               |     pyhd3eb1b0_0          31 KB
#     certifi-2020.12.5          |   py37h06a4308_0         143 KB
#     idna-2.10                  |     pyhd3eb1b0_0          52 KB
#     asn1crypto-1.4.0           |             py_0          77 KB
#     pysocks-1.7.1              |           py37_1          27 KB
#     pycosat-0.6.3              |   py37h27cfd23_0         108 KB
#     requests-2.25.1            |     pyhd3eb1b0_0          51 KB
#     ruamel_yaml-0.15.100       |   py37h27cfd23_0         267 KB
#     _libgcc_mutex-0.1          |             main           3 KB
#     chardet-4.0.0              |py37h06a4308_1003         205 KB
#     conda-4.10.1               |   py37h06a4308_1         3.1 MB
#     libedit-3.1.20181209       |       hc058e9b_0         188 KB
#     openssl-1.0.2u             |       h7b6447c_0         3.1 MB
#     urllib3-1.26.4             |     pyhd3eb1b0_0          99 KB
#     setuptools-52.0.0          |   py37h06a4308_0         921 KB
#     brotlipy-0.7.0             |py37h27cfd23_1003         350 KB
#     sqlite-3.31.1              |       h7b6447c_0         2.0 MB
#     six-1.15.0                 |     pyhd3eb1b0_0          13 KB
#     ca-certificates-2021.4.13  |       h06a4308_1         120 KB
#     readline-7.0               |       h7b6447c_5         392 KB
#     python-3.7.0               |       hc3d631a_0        31.7 MB
#     pip-21.1.1                 |   py37h06a4308_0         2.0 MB
#     cffi-1.14.0                |   py37h2e261b9_0         225 KB
#     pyopenssl-19.0.0           |           py37_0          82 KB
#     xz-5.2.5                   |       h7b6447c_0         438 KB
#     conda-package-handling-1.7.3|   py37h27cfd23_1         962 KB
#     tk-8.6.10                  |       hbc83047_0         3.2 MB
#     tqdm-4.59.0                |     pyhd3eb1b0_1          90 KB
#     ------------------------------------------------------------
#                                            Total:        58.8 MB
#
# The following NEW packages will be INSTALLED:
#
#     _libgcc_mutex:          0.1-main
#     brotlipy:               0.7.0-py37h27cfd23_1003
#     conda-package-handling: 1.7.3-py37h27cfd23_1
#     tqdm:                   4.59.0-pyhd3eb1b0_1
#
# The following packages will be UPDATED:
#
#     asn1crypto:             0.24.0-py36_0           --> 1.4.0-py_0
#     ca-certificates:        2018.03.07-0            --> 2021.4.13-h06a4308_1
#     certifi:                2018.4.16-py36_0        --> 2020.12.5-py37h06a4308_0
#     cffi:                   1.11.5-py36h9745a5d_0   --> 1.14.0-py37h2e261b9_0
#     chardet:                3.0.4-py36h0f667ec_1    --> 4.0.0-py37h06a4308_1003
#     conda:                  4.5.4-py36_0            --> 4.10.1-py37h06a4308_1
#     cryptography:           2.2.2-py36h14c3975_0    --> 2.3.1-py37hc365091_0
#     idna:                   2.6-py36h82fb2a8_1      --> 2.10-pyhd3eb1b0_0
#     libedit:                3.1.20170329-h6b74fdf_2 --> 3.1.20181209-hc058e9b_0
#     libgcc-ng:              7.2.0-hdf63c60_3        --> 9.1.0-hdf63c60_0
#     openssl:                1.0.2o-h20670df_0       --> 1.0.2u-h7b6447c_0
#     pip:                    10.0.1-py36_0           --> 21.1.1-py37h06a4308_0
#     pycosat:                0.6.3-py36h0a5515d_0    --> 0.6.3-py37h27cfd23_0
#     pycparser:              2.18-py36hf9f622e_1     --> 2.20-py_2
#     pyopenssl:              18.0.0-py36_0           --> 19.0.0-py37_0
#     pysocks:                1.6.8-py36_0            --> 1.7.1-py37_1
#     python:                 3.6.5-hc3d631a_2        --> 3.7.0-hc3d631a_0
#     readline:               7.0-ha6073c6_4          --> 7.0-h7b6447c_5
#     requests:               2.18.4-py36he2e5f8d_1   --> 2.25.1-pyhd3eb1b0_0
#     ruamel_yaml:            0.15.37-py36h14c3975_2  --> 0.15.100-py37h27cfd23_0
#     setuptools:             39.2.0-py36_0           --> 52.0.0-py37h06a4308_0
#     six:                    1.11.0-py36h372c433_1   --> 1.15.0-pyhd3eb1b0_0
#     sqlite:                 3.23.1-he433501_0       --> 3.31.1-h7b6447c_0
#     tk:                     8.6.7-hc745277_3        --> 8.6.10-hbc83047_0
#     urllib3:                1.22-py36hbe7ace6_0     --> 1.26.4-pyhd3eb1b0_0
#     wheel:                  0.31.1-py36_0           --> 0.36.2-pyhd3eb1b0_0
#     xz:                     5.2.4-h14c3975_4        --> 5.2.5-h7b6447c_0
#     yaml:                   0.1.7-had09818_2        --> 0.2.5-h7b6447c_0
#     zlib:                   1.2.11-ha838bed_2       --> 1.2.11-h7b6447c_3
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.7/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - _license
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
# !conda env create -f reco_base.yaml
# Out:
# done
# done
#
# Downloading and Extracting Packages
# prometheus_client-0. | 46 KB     | : 100% 1.0/1 [00:00<00:00,  4.74it/s]
# mkl-service-2.3.0    | 52 KB     | : 100% 1.0/1 [00:00<00:00,  7.98it/s]
# tornado-6.1          | 581 KB    | : 100% 1.0/1 [00:00<00:00,  5.57it/s]
# glib-2.68.2          | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  3.62it/s]
# readline-8.1         | 362 KB    | : 100% 1.0/1 [00:00<00:00,  7.67it/s]
# gst-plugins-base-1.1 | 4.9 MB    | : 100% 1.0/1 [00:00<00:00,  3.76it/s]
# traitlets-4.3.3      | 140 KB    | : 100% 1.0/1 [00:00<00:00,  8.80it/s]
# libgcc-ng-9.3.0      | 7.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.78s/it]
# certifi-2020.12.5    | 140 KB    | : 100% 1.0/1 [00:00<00:00,  9.32it/s]
# cryptography-3.4.7   | 903 KB    | : 100% 1.0/1 [00:00<00:00,  6.54it/s]
# jsonschema-3.2.0     | 47 KB     | : 100% 1.0/1 [00:00<00:00,  8.76it/s]
# jupyter_console-6.4. | 23 KB     | : 100% 1.0/1 [00:00<00:00,  9.57it/s]
# ipython_genutils-0.2 | 27 KB     | : 100% 1.0/1 [00:00<00:00,  9.40it/s]
# defusedxml-0.7.1     | 23 KB     | : 100% 1.0/1 [00:00<00:00,  9.55it/s]
# lightfm-1.15         | 375 KB    | : 100% 1.0/1 [00:00<00:00,  6.78it/s]
# qt-5.9.7             | 68.5 MB   | : 100% 1.0/1 [00:03<00:00,  3.32s/it]
# pytorch-cpu-1.3.1    | 2 KB      | : 100% 1.0/1 [00:00<00:00,  9.91it/s]
# lz4-c-1.9.3          | 186 KB    | : 100% 1.0/1 [00:00<00:00,  9.34it/s]
# pyyaml-5.4.1         | 170 KB    | : 100% 1.0/1 [00:00<00:00,  8.30it/s]
# pyopenssl-20.0.1     | 49 KB     | : 100% 1.0/1 [00:00<00:00,  9.71it/s]
# threadpoolctl-2.1.0  | 17 KB     | : 100% 1.0/1 [00:00<00:00,  9.26it/s]
# pcre-8.44            | 212 KB    | : 100% 1.0/1 [00:00<00:00,  8.75it/s]
# sip-4.19.8           | 274 KB    | : 100% 1.0/1 [00:00<00:00,  9.34it/s]
# send2trash-1.5.0     | 14 KB     | : 100% 1.0/1 [00:00<00:00,  7.42it/s]
# numba-0.53.1         | 3.3 MB    | : 100% 1.0/1 [00:00<00:00,  2.53it/s]
# importlib_metadata-3 | 11 KB     | : 100% 1.0/1 [00:00<00:00,  8.60it/s]
# nbconvert-6.0.7      | 480 KB    | : 100% 1.0/1 [00:00<00:00,  5.40it/s]
# olefile-0.46         | 48 KB     | : 100% 1.0/1 [00:00<00:00,  7.31it/s]
# libgomp-9.3.0        | 376 KB    | : 100% 1.0/1 [00:00<00:00,  8.74it/s]
# freetype-2.10.4      | 596 KB    | : 100% 1.0/1 [00:00<00:00,  6.80it/s]
# seaborn-0.11.1       | 212 KB    | : 100% 1.0/1 [00:00<00:00,  7.64it/s]
# py-1.10.0            | 76 KB     | : 100% 1.0/1 [00:00<00:00,  8.31it/s]
# pytz-2021.1          | 181 KB    | : 100% 1.0/1 [00:00<00:00,  5.80it/s]
# cloudpickle-1.6.0    | 30 KB     | : 100% 1.0/1 [00:00<00:00,  7.99it/s]
# jinja2-3.0.0         | 106 KB    | : 100% 1.0/1 [00:00<00:00,  8.05it/s]
# libtiff-4.1.0        | 449 KB    | : 100% 1.0/1 [00:00<00:00,  7.00it/s]
# bottleneck-1.2.1     | 120 KB    | : 100% 1.0/1 [00:00<00:00,  7.97it/s]
# lightgbm-2.2.1       | 836 KB    | : 100% 1.0/1 [00:00<00:00,  7.00it/s]
# pandoc-2.12          | 9.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.45it/s]
# pygments-2.9.0       | 721 KB    | : 100% 1.0/1 [00:00<00:00,  5.34it/s]
# nbformat-5.1.3       | 44 KB     | : 100% 1.0/1 [00:00<00:00,  7.36it/s]
# parso-0.8.2          | 69 KB     | : 100% 1.0/1 [00:00<00:00,  8.68it/s]
# jupyter_core-4.7.1   | 68 KB     | : 100% 1.0/1 [00:00<00:00,  7.74it/s]
# markupsafe-2.0.1     | 21 KB     | : 100% 1.0/1 [00:00<00:00,  8.40it/s]
# iniconfig-1.1.1      | 8 KB      | : 100% 1.0/1 [00:00<00:00, 35.64it/s]
# prompt-toolkit-3.0.1 | 256 KB    | : 100% 1.0/1 [00:00<00:00,  7.38it/s]
# libxcb-1.14          | 505 KB    | : 100% 1.0/1 [00:00<00:00,  6.30it/s]
# toml-0.10.2          | 20 KB     | : 100% 1.0/1 [00:00<00:00,  8.75it/s]
# pexpect-4.8.0        | 53 KB     | : 100% 1.0/1 [00:00<00:00,  7.44it/s]
# locket-0.2.1         | 10 KB     | : 100% 1.0/1 [00:00<00:00,  8.91it/s]
# kiwisolver-1.3.1     | 80 KB     | : 100% 1.0/1 [00:00<00:00,  8.35it/s]
# notebook-6.4.0       | 4.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.05it/s]
# nbclient-0.5.3       | 62 KB     | : 100% 1.0/1 [00:00<00:00,  7.90it/s]
# prompt_toolkit-3.0.1 | 12 KB     | : 100% 1.0/1 [00:00<00:00,  8.37it/s]
# pyparsing-2.4.7      | 59 KB     | : 100% 1.0/1 [00:00<00:00, 25.28it/s]
# black-19.10b0        | 86 KB     | : 100% 1.0/1 [00:00<00:00,  8.58it/s]
# jedi-0.17.0          | 780 KB    | : 100% 1.0/1 [00:00<00:00,  3.27it/s]
# async_generator-1.10 | 39 KB     | : 100% 1.0/1 [00:00<00:00,  8.23it/s]
# more-itertools-8.7.0 | 42 KB     | : 100% 1.0/1 [00:00<00:00,  8.75it/s]
# ansiwrap-0.8.4       | 9 KB      | : 100% 1.0/1 [00:00<00:00, 25.50it/s]
# pytorch-1.3.1        | 24.9 MB   | : 100% 1.0/1 [00:01<00:00,  1.72s/it]
# python_abi-3.6       | 4 KB      | : 100% 1.0/1 [00:00<00:00, 27.80it/s]
# six-1.15.0           | 27 KB     | : 100% 1.0/1 [00:00<00:00,  8.78it/s]
# heapdict-1.0.1       | 9 KB      | : 100% 1.0/1 [00:00<00:00,  8.08it/s]
# terminado-0.9.4      | 25 KB     | : 100% 1.0/1 [00:00<00:00,  8.29it/s]
# bokeh-2.3.2          | 5.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.45it/s]
# fastparquet-0.5.0    | 176 KB    | : 100% 1.0/1 [00:00<00:00,  8.15it/s]
# pandocfilters-1.4.3  | 14 KB     | : 100% 1.0/1 [00:00<00:00,  8.80it/s]
# nltk-3.6.2           | 988 KB    | : 100% 1.0/1 [00:00<00:00,  5.48it/s]
# ld_impl_linux-64-2.3 | 618 KB    | : 100% 1.0/1 [00:00<00:00,  5.36it/s]
# testpath-0.4.4       | 85 KB     | : 100% 1.0/1 [00:00<00:00, 25.90it/s]
# nest-asyncio-1.5.1   | 10 KB     | : 100% 1.0/1 [00:00<00:00,  9.30it/s]
# pillow-8.2.0         | 627 KB    | : 100% 1.0/1 [00:00<00:00,  7.50it/s]
# bleach-3.3.0         | 113 KB    | : 100% 1.0/1 [00:00<00:00,  8.57it/s]
# openssl-1.1.1k       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  4.20it/s]
# psutil-5.8.0         | 329 KB    | : 100% 1.0/1 [00:00<00:00,  7.39it/s]
# libstdcxx-ng-9.3.0   | 4.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.11it/s]
# libuuid-1.0.3        | 15 KB     | : 100% 1.0/1 [00:00<00:00,  9.00it/s]
# pyqt-5.9.2           | 4.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.92it/s]
# scikit-learn-0.24.2  | 5.2 MB    | : 100% 1.0/1 [00:00<00:00,  2.01it/s]
# jupyterlab_pygments- | 8 KB      | : 100% 1.0/1 [00:00<00:00,  9.52it/s]
# mkl_random-1.1.1     | 327 KB    | : 100% 1.0/1 [00:00<00:00,  8.56it/s]
# matplotlib-3.3.4     | 26 KB     | : 100% 1.0/1 [00:00<00:00,  8.46it/s]
# pyzmq-20.0.0         | 438 KB    | : 100% 1.0/1 [00:00<00:00,  6.43it/s]
# ncurses-6.2          | 817 KB    | : 100% 1.0/1 [00:00<00:00,  2.90it/s]
# pickleshare-0.7.5    | 13 KB     | : 100% 1.0/1 [00:00<00:00,  8.91it/s]
# typing_extensions-3. | 25 KB     | : 100% 1.0/1 [00:00<00:00, 31.50it/s]
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00, 27.72it/s]
# appdirs-1.4.4        | 13 KB     | : 100% 1.0/1 [00:00<00:00,  7.31it/s]
# backcall-0.2.0       | 13 KB     | : 100% 1.0/1 [00:00<00:00, 37.10it/s]
# dbus-1.13.18         | 504 KB    | : 100% 1.0/1 [00:00<00:00,  7.35it/s]
# tblib-1.7.0          | 16 KB     | : 100% 1.0/1 [00:00<00:00,  8.55it/s]
# zstd-1.4.9           | 480 KB    | : 100% 1.0/1 [00:00<00:00,  7.75it/s]
# setuptools-52.0.0    | 724 KB    | : 100% 1.0/1 [00:00<00:00,  5.78it/s]
# thrift-0.11.0        | 105 KB    | : 100% 1.0/1 [00:00<00:00,  8.20it/s]
# numpy-1.19.2         | 22 KB     | : 100% 1.0/1 [00:00<00:00,  8.12it/s]
# wcwidth-0.2.5        | 29 KB     | : 100% 1.0/1 [00:00<00:00,  8.35it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00,  9.13it/s]
# libpng-1.6.37        | 278 KB    | : 100% 1.0/1 [00:00<00:00,  7.77it/s]
# tbb-2020.3           | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  6.21it/s]
# ipython-7.16.1       | 999 KB    | : 100% 1.0/1 [00:00<00:00,  4.75it/s]
# pyrsistent-0.17.3    | 89 KB     | : 100% 1.0/1 [00:00<00:00,  8.61it/s]
# immutables-0.15      | 68 KB     | : 100% 1.0/1 [00:00<00:00,  7.87it/s]
# decorator-5.0.9      | 12 KB     | : 100% 1.0/1 [00:00<00:00,  8.89it/s]
# cytoolz-0.11.0       | 329 KB    | : 100% 1.0/1 [00:00<00:00,  7.70it/s]
# libgfortran-ng-7.3.0 | 1006 KB   | : 100% 1.0/1 [00:00<00:00,  6.55it/s]
# fontconfig-2.13.1    | 250 KB    | : 100% 1.0/1 [00:00<00:00,  7.75it/s]
# mypy_extensions-0.4. | 9 KB      | : 100% 1.0/1 [00:00<00:00,  8.39it/s]
# scikit-surprise-1.1. | 588 KB    | : 100% 1.0/1 [00:00<00:00,  3.39it/s]
# webencodings-0.5.1   | 19 KB     | : 100% 1.0/1 [00:00<00:00,  8.66it/s]
# zict-2.0.0           | 10 KB     | : 100% 1.0/1 [00:00<00:00, 37.81it/s]
# typed-ast-1.4.2      | 186 KB    | : 100% 1.0/1 [00:00<00:00,  8.38it/s]
# msgpack-python-1.0.2 | 82 KB     | : 100% 1.0/1 [00:00<00:00,  8.41it/s]
# _openmp_mutex-4.5    | 22 KB     | : 100% 1.0/1 [00:00<00:00, 24.86it/s]
# partd-1.2.0          | 19 KB     | : 100% 1.0/1 [00:00<00:00,  8.89it/s]
# chardet-4.0.0        | 199 KB    | : 100% 1.0/1 [00:00<00:00,  8.68it/s]
# _pytorch_select-0.1  | 3 KB      | : 100% 1.0/1 [00:00<00:00,  7.94it/s]
# dask-2021.3.0        | 5 KB      | : 100% 1.0/1 [00:00<00:00, 10.01it/s]
# llvmlite-0.36.0      | 393 KB    | : 100% 1.0/1 [00:00<00:00,  7.49it/s]
# importlib-metadata-3 | 33 KB     | : 100% 1.0/1 [00:00<00:00,  8.33it/s]
# ipywidgets-7.6.3     | 105 KB    | : 100% 1.0/1 [00:00<00:00,  7.24it/s]
# qtpy-1.9.0           | 38 KB     | : 100% 1.0/1 [00:00<00:00,  9.31it/s]
# libllvm10-10.0.1     | 22.1 MB   | : 100% 1.0/1 [00:01<00:00,  1.02s/it]
# mkl-2020.2           | 138.3 MB  | : 100% 1.0/1 [00:06<00:00,  6.24s/it]
# textwrap3-0.9.2      | 12 KB     | : 100% 1.0/1 [00:00<00:00, 17.46it/s]
# toolz-0.11.1         | 46 KB     | : 100% 1.0/1 [00:00<00:00, 25.68it/s]
# argon2-cffi-20.1.0   | 46 KB     | : 100% 1.0/1 [00:00<00:00,  9.64it/s]
# distributed-2021.3.0 | 1.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.98it/s]
# libxml2-2.9.10       | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  5.90it/s]
# contextvars-2.4      | 12 KB     | : 100% 1.0/1 [00:00<00:00,  9.69it/s]
# expat-2.3.0          | 158 KB    | : 100% 1.0/1 [00:00<00:00,  9.62it/s]
# zeromq-4.3.4         | 331 KB    | : 100% 1.0/1 [00:00<00:00,  8.36it/s]
# pluggy-0.13.1        | 33 KB     | : 100% 1.0/1 [00:00<00:00, 10.06it/s]
# jupyter_client-6.1.1 | 88 KB     | : 100% 1.0/1 [00:00<00:00,  8.47it/s]
# pip-21.1.1           | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  3.78it/s]
# pysocks-1.7.1        | 31 KB     | : 100% 1.0/1 [00:00<00:00,  8.85it/s]
# libffi-3.3           | 50 KB     | : 100% 1.0/1 [00:00<00:00,  8.82it/s]
# papermill-2.3.3      | 32 KB     | : 100% 1.0/1 [00:00<00:00, 18.65it/s]
# click-8.0.1          | 79 KB     | : 100% 1.0/1 [00:00<00:00,  8.88it/s]
# numpy-base-1.19.2    | 4.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.77it/s]
# libsodium-1.0.18     | 244 KB    | : 100% 1.0/1 [00:00<00:00,  9.13it/s]
# attrs-21.2.0         | 46 KB     | : 100% 1.0/1 [00:00<00:00, 10.08it/s]
# pandas-1.1.5         | 8.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.45it/s]
# sortedcontainers-2.3 | 26 KB     | : 100% 1.0/1 [00:00<00:00,  9.83it/s]
# jpeg-9b              | 214 KB    | : 100% 1.0/1 [00:00<00:00,  8.94it/s]
# sqlite-3.35.4        | 981 KB    | : 100% 1.0/1 [00:00<00:00,  7.27it/s]
# python-dateutil-2.8. | 221 KB    | : 100% 1.0/1 [00:00<00:00, 14.95it/s]
# ninja-1.10.2         | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  6.52it/s]
# icu-58.2             | 10.5 MB   | : 100% 1.0/1 [00:00<00:00,  1.76it/s]
# regex-2021.4.4       | 319 KB    | : 100% 1.0/1 [00:00<00:00,  7.43it/s]
# zipp-3.4.1           | 15 KB     | : 100% 1.0/1 [00:00<00:00,  8.42it/s]
# dask-core-2021.3.0   | 659 KB    | : 100% 1.0/1 [00:00<00:00,  5.90it/s]
# swig-3.0.12          | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  4.62it/s]
# gstreamer-1.14.0     | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  4.06it/s]
# lcms2-2.12           | 312 KB    | : 100% 1.0/1 [00:00<00:00,  8.19it/s]
# cffi-1.14.5          | 222 KB    | : 100% 1.0/1 [00:00<00:00,  9.07it/s]
# cycler-0.10.0        | 13 KB     | : 100% 1.0/1 [00:00<00:00,  9.50it/s]
# ipykernel-5.3.4      | 181 KB    | : 100% 1.0/1 [00:00<00:00,  8.45it/s]
# pytest-6.2.3         | 420 KB    | : 100% 1.0/1 [00:00<00:00,  7.63it/s]
# scipy-1.5.2          | 14.4 MB   | : 100% 1.0/1 [00:00<00:00,  1.34it/s]
# matplotlib-base-3.3. | 5.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.89it/s]
# tenacity-7.0.0       | 32 KB     | : 100% 1.0/1 [00:00<00:00,  9.76it/s]
# brotlipy-0.7.0       | 320 KB    | : 100% 1.0/1 [00:00<00:00,  8.86it/s]
# packaging-20.9       | 37 KB     | : 100% 1.0/1 [00:00<00:00,  9.85it/s]
# qtconsole-5.0.3      | 97 KB     | : 100% 1.0/1 [00:00<00:00,  9.56it/s]
# jupyter-1.0.0        | 6 KB      | : 100% 1.0/1 [00:00<00:00,  9.42it/s]
# fsspec-0.9.0         | 83 KB     | : 100% 1.0/1 [00:00<00:00,  9.75it/s]
# cornac-1.12.0        | 3.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.37it/s]
# jupyterlab_widgets-1 | 109 KB    | : 100% 1.0/1 [00:00<00:00,  9.38it/s]
# joblib-1.0.1         | 208 KB    | : 100% 1.0/1 [00:00<00:00,  8.42it/s]
# intel-openmp-2021.2. | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  6.80it/s]
# widgetsnbextension-3 | 862 KB    | : 100% 1.0/1 [00:00<00:00,  6.69it/s]
# mock-2.0.0           | 108 KB    | : 100% 1.0/1 [00:00<00:00,  9.41it/s]
# mistune-0.8.4        | 55 KB     | : 100% 1.0/1 [00:00<00:00,  9.00it/s]
# pathspec-0.7.0       | 26 KB     | : 100% 1.0/1 [00:00<00:00,  9.22it/s]
# ptyprocess-0.7.0     | 17 KB     | : 100% 1.0/1 [00:00<00:00,  9.97it/s]
# entrypoints-0.3      | 12 KB     | : 100% 1.0/1 [00:00<00:00, 10.26it/s]
# pbr-5.6.0            | 74 KB     | : 100% 1.0/1 [00:00<00:00,  9.43it/s]
# mkl_fft-1.3.0        | 170 KB    | : 100% 1.0/1 [00:00<00:00,  8.05it/s]
# python-3.6.11        | 38.3 MB   | : 100% 1.0/1 [00:08<00:00,  8.12s/it]
# done
# done
# -
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# / Ran pip subprocess with arguments:
# ['/usr/local/envs/reco_base/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/Recommenders/condaenv.c0ravc4l.requirements.txt']
# Pip subprocess output:
# Collecting azureml-sdk[notebooks,tensorboard]==1.0.69
#   Downloading azureml_sdk-1.0.69-py3-none-any.whl (4.6 kB)
# Collecting azure-storage-blob<=2.1.0
#   Downloading azure_storage_blob-2.1.0-py2.py3-none-any.whl (88 kB)
# Collecting azure-cli-core==2.0.75
#   Downloading azure_cli_core-2.0.75-py2.py3-none-any.whl (125 kB)
# Collecting azure-mgmt-cosmosdb==0.8.0
#   Downloading azure_mgmt_cosmosdb-0.8.0-py2.py3-none-any.whl (73 kB)
# Requirement already satisfied: black>=18.6b4 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from -r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 5)) (19.10b0)
# Collecting black>=18.6b4
#   Downloading black-21.5b1-py3-none-any.whl (137 kB)
# Collecting category_encoders>=1.3.0
#   Downloading category_encoders-2.2.2-py2.py3-none-any.whl (80 kB)
# Collecting dataclasses>=0.6
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting hyperopt==0.1.2
#   Downloading hyperopt-0.1.2-py3-none-any.whl (115 kB)
# Collecting idna==2.7
#   Downloading idna-2.7-py2.py3-none-any.whl (58 kB)
# Collecting locustio==0.11.0
#   Downloading locustio-0.11.0-py2.py3-none-any.whl (240 kB)
# Collecting memory-profiler>=0.54.0
#   Downloading memory_profiler-0.58.0.tar.gz (36 kB)
# Collecting nbconvert==5.5.0
#   Downloading nbconvert-5.5.0-py2.py3-none-any.whl (447 kB)
# Collecting pydocumentdb>=2.3.3
#   Downloading pydocumentdb-2.3.5-py3-none-any.whl (93 kB)
# Collecting pymanopt==0.2.5
#   Downloading pymanopt-0.2.5-py3-none-any.whl (59 kB)
# Collecting xlearn==0.40a1
#   Downloading xlearn-0.40a1.tar.gz (4.9 MB)
# Collecting transformers==2.5.0
#   Downloading transformers-2.5.0-py3-none-any.whl (481 kB)
# Collecting tensorflow==1.15.4
#   Downloading tensorflow-1.15.4-cp36-cp36m-manylinux2010_x86_64.whl (110.5 MB)
# Collecting scrapbook>=0.5.0
#   Downloading scrapbook-0.5.0-py3-none-any.whl (34 kB)
# Collecting nni==1.5
#   Downloading nni-1.5-py3-none-manylinux1_x86_64.whl (36.0 MB)
# Collecting msrestazure>=0.6.2
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting wheel==0.30.0
#   Downloading wheel-0.30.0-py2.py3-none-any.whl (49 kB)
# Requirement already satisfied: pyyaml in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azure-cli-core==2.0.75->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 3)) (5.4.1)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.7.2-py2.py3-none-any.whl (206 kB)
# Collecting argcomplete~=1.8
#   Downloading argcomplete-1.12.3-py2.py3-none-any.whl (38 kB)
# Collecting PyJWT
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: pyopenssl>=17.1.0 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azure-cli-core==2.0.75->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 3)) (20.0.1)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: requests~=2.20 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azure-cli-core==2.0.75->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 3)) (2.25.1)
# Collecting msrest>=0.4.4
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting antlr4-python3-runtime
#   Downloading antlr4-python3-runtime-4.9.2.tar.gz (117 kB)
# Collecting azure-cli-telemetry
#   Downloading azure_cli_telemetry-1.0.6-py3-none-any.whl (10 kB)
# Collecting azure-mgmt-resource~=4.0
#   Downloading azure_mgmt_resource-4.0.0-py2.py3-none-any.whl (657 kB)
# Collecting azure-cli-nspkg>=2.0.0
#   Downloading azure_cli_nspkg-3.0.4-py3-none-any.whl (1.8 kB)
# Requirement already satisfied: six in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azure-cli-core==2.0.75->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 3)) (1.15.0)
# Collecting adal~=1.2
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting humanfriendly~=4.7
#   Downloading humanfriendly-4.18-py2.py3-none-any.whl (73 kB)
# Collecting colorama>=0.3.9
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting knack~=0.6.2
#   Downloading knack-0.6.3-py2.py3-none-any.whl (54 kB)
# Collecting azure-common~=1.1
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: scipy in /usr/local/envs/reco_base/lib/python3.6/site-packages (from hyperopt==0.1.2->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 8)) (1.5.2)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
# Collecting pymongo
#   Downloading pymongo-3.11.4-cp36-cp36m-manylinux2014_x86_64.whl (509 kB)
# Requirement already satisfied: numpy in /usr/local/envs/reco_base/lib/python3.6/site-packages (from hyperopt==0.1.2->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 8)) (1.19.2)
# Collecting networkx
#   Downloading networkx-2.5.1-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: tqdm in /usr/local/envs/reco_base/lib/python3.6/site-packages (from hyperopt==0.1.2->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 8)) (4.59.0)
# Requirement already satisfied: pyzmq>=16.0.2 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from locustio==0.11.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 10)) (20.0.0)
# Collecting flask>=0.10.1
#   Downloading Flask-2.0.1-py3-none-any.whl (94 kB)
# Collecting gevent>=1.2.2
#   Downloading gevent-21.1.2-cp36-cp36m-manylinux2010_x86_64.whl (5.5 MB)
# Requirement already satisfied: msgpack>=0.4.2 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from locustio==0.11.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 10)) (1.0.2)
# Requirement already satisfied: mistune>=0.8.1 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (1.4.3)
# Requirement already satisfied: jupyter-core in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (4.7.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (4.3.3)
# Requirement already satisfied: bleach in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (3.3.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (0.3)
# Requirement already satisfied: testpath in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (0.4.4)
# Requirement already satisfied: defusedxml in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (0.7.1)
# Requirement already satisfied: pygments in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (2.9.0)
# Requirement already satisfied: nbformat>=4.4 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (5.1.3)
# Requirement already satisfied: jinja2>=2.4 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from transformers==2.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 16)) (2021.4.4)
# Collecting tokenizers==0.5.0
#   Downloading tokenizers-0.5.0-cp36-cp36m-manylinux1_x86_64.whl (3.8 MB)
# Collecting boto3
#   Downloading boto3-1.17.78.tar.gz (98 kB)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
# Collecting filelock
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.95-cp36-cp36m-manylinux2014_x86_64.whl (1.2 MB)
# Collecting keras-preprocessing>=1.0.5
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting numpy
#   Downloading numpy-1.18.5-cp36-cp36m-manylinux1_x86_64.whl (20.1 MB)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Collecting astor>=0.6.0
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting protobuf>=3.6.1
#   Downloading protobuf-3.17.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting absl-py>=0.7.0
#   Downloading absl_py-0.12.0-py3-none-any.whl (129 kB)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
# Collecting wrapt>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting google-pasta>=0.1.6
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting grpcio>=1.8.6
#   Downloading grpcio-1.38.0-cp36-cp36m-manylinux2014_x86_64.whl (4.2 MB)
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: psutil in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nni==1.5->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 19)) (5.8.0)
# Collecting schema
#   Downloading schema-0.7.4-py2.py3-none-any.whl (16 kB)
# Collecting PythonWebHDFS
#   Downloading PythonWebHDFS-0.2.3-py3-none-any.whl (10 kB)
# Collecting ruamel.yaml
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting json-tricks
#   Downloading json_tricks-3.15.5-py2.py3-none-any.whl (26 kB)
# Collecting coverage
#   Downloading coverage-5.5-cp36-cp36m-manylinux2010_x86_64.whl (240 kB)
# Collecting scikit-learn<0.22,>=0.20
#   Downloading scikit_learn-0.21.3-cp36-cp36m-manylinux1_x86_64.whl (6.7 MB)
# Collecting azureml-dataprep[fuse]<1.2.0a,>=1.1.20a
#   Downloading azureml_dataprep-1.1.38-py3-none-any.whl (26.9 MB)
# Collecting azureml-train==1.0.69.*
#   Downloading azureml_train-1.0.69-py3-none-any.whl (3.2 kB)
# Collecting azureml-pipeline==1.0.69.*
#   Downloading azureml_pipeline-1.0.69-py3-none-any.whl (3.7 kB)
# Collecting azureml-core==1.0.69.*
#   Downloading azureml_core-1.0.69-py2.py3-none-any.whl (1.1 MB)
# Collecting azureml-tensorboard==1.0.69.*
#   Downloading azureml_tensorboard-1.0.69-py3-none-any.whl (10 kB)
# Collecting azureml-widgets==1.0.69.*
#   Downloading azureml_widgets-1.0.69.1-py3-none-any.whl (9.3 MB)
# Collecting azureml-contrib-notebook==1.0.69.*
#   Downloading azureml_contrib_notebook-1.0.69-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: papermill in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: ipython in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (7.16.1)
# Requirement already satisfied: ipykernel in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (5.3.4)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azureml-core==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (3.4.7)
# Requirement already satisfied: pathspec in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azureml-core==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (0.7.0)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-9.0.0-py2.py3-none-any.whl (312 kB)
# Collecting ruamel.yaml
#   Downloading ruamel.yaml-0.15.89-cp36-cp36m-manylinux1_x86_64.whl (651 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-1.0.0-py2.py3-none-any.whl (141 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting docker
#   Downloading docker-5.0.0-py2.py3-none-any.whl (146 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-18.0.0-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: pytz in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azureml-core==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (2021.1)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azureml-core==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (2.8.1)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: urllib3>=1.23 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azureml-core==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (1.26.4)
# Collecting azureml-pipeline-steps==1.0.69.*
#   Downloading azureml_pipeline_steps-1.0.69-py3-none-any.whl (40 kB)
# Collecting azureml-pipeline-core==1.0.69.*
#   Downloading azureml_pipeline_core-1.0.69-py2.py3-none-any.whl (260 kB)
# Collecting azureml-train-core==1.0.69.*
#   Downloading azureml_train_core-1.0.69-py3-none-any.whl (77 kB)
# Collecting azureml-train-restclients-hyperdrive==1.0.69.*
#   Downloading azureml_train_restclients_hyperdrive-1.0.69-py3-none-any.whl (17 kB)
# Collecting azureml-telemetry==1.0.69.*
#   Downloading azureml_telemetry-1.0.69-py3-none-any.whl (30 kB)
# Collecting applicationinsights
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azureml-widgets==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (7.6.3)
# Collecting azure-storage-common~=2.1
#   Downloading azure_storage_common-2.1.0-py2.py3-none-any.whl (47 kB)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from black>=18.6b4->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 5)) (0.4.3)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: typed-ast>=1.4.2 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from black>=18.6b4->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: toml>=0.10.1 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from black>=18.6b4->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 5)) (0.10.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from black>=18.6b4->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 5)) (3.7.4.3)
# Requirement already satisfied: click>=7.1.2 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from black>=18.6b4->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 5)) (8.0.1)
# Requirement already satisfied: appdirs in /usr/local/envs/reco_base/lib/python3.6/site-packages (from black>=18.6b4->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 5)) (1.4.4)
# Collecting statsmodels>=0.9.0
#   Downloading statsmodels-0.12.2-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting patsy>=0.5.1
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from category_encoders>=1.3.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 6)) (1.1.5)
# Collecting pyarrow
#   Downloading pyarrow-4.0.0-cp36-cp36m-manylinux2014_x86_64.whl (21.9 MB)
# Requirement already satisfied: jsonschema in /usr/local/envs/reco_base/lib/python3.6/site-packages (from scrapbook>=0.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 18)) (3.2.0)
# Requirement already satisfied: importlib-metadata<5,>=0.23 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from argcomplete~=1.8->azure-cli-core==2.0.75->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 3)) (3.10.0)
# Collecting azure-nspkg>=2.0.0
#   Downloading azure_nspkg-3.0.2-py3-none-any.whl (1.5 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.2.2-py2.py3-none-any.whl (21 kB)
# Collecting azure-core<2.0.0,>=1.9.0
#   Downloading azure_core-1.14.0-py2.py3-none-any.whl (136 kB)
# Collecting dotnetcore2>=2.1.9
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Requirement already satisfied: cloudpickle>=1.1.0 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.2.0a,>=1.1.20a->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (1.6.0)
# Collecting azureml-dataprep-native<14.0.0,>=13.2.0
#   Downloading azureml_dataprep_native-13.2.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting fusepy>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (1.14.5)
# Requirement already satisfied: pycparser in /usr/local/envs/reco_base/lib/python3.6/site-packages (from cffi>=1.12->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (2.20)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.0.1-py3-none-any.whl (288 kB)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: setuptools in /usr/local/envs/reco_base/lib/python3.6/site-packages (from gevent>=1.2.2->locustio==0.11.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 10)) (52.0.0.post20210125)
# Collecting zope.event
#   Downloading zope.event-4.5.0-py2.py3-none-any.whl (6.8 kB)
# Collecting greenlet<2.0,>=0.4.17
#   Downloading greenlet-1.1.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (155 kB)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp36-cp36m-manylinux2010_x86_64.whl (251 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from importlib-metadata<5,>=0.23->argcomplete~=1.8->azure-cli-core==2.0.75->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml-widgets==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml-widgets==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (3.5.1)
# Requirement already satisfied: tornado>=4.2 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from ipykernel->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (6.1)
# Requirement already satisfied: jupyter-client in /usr/local/envs/reco_base/lib/python3.6/site-packages (from ipykernel->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (6.1.12)
# Requirement already satisfied: jedi>=0.10 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: backcall in /usr/local/envs/reco_base/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/envs/reco_base/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/envs/reco_base/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (5.0.9)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (3.0.17)
# Requirement already satisfied: pexpect in /usr/local/envs/reco_base/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: parso>=0.7.0 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from jedi>=0.10->ipython->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from jinja2>=2.4->nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (2.0.1)
# Collecting h5py
#   Downloading h5py-3.1.0-cp36-cp36m-manylinux1_x86_64.whl (4.0 MB)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from msrest>=0.4.4->azure-cli-core==2.0.75->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 3)) (2020.12.5)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied: ipython-genutils in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbformat>=4.4->nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from jsonschema->scrapbook>=0.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 18)) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from jsonschema->scrapbook>=0.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 18)) (0.17.3)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961 kB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux2010_x86_64.whl (63 kB)
# Requirement already satisfied: wcwidth in /usr/local/envs/reco_base/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from requests~=2.20->azure-cli-core==2.0.75->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 3)) (4.0.0)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from scikit-learn<0.22,>=0.20->nni==1.5->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 19)) (1.0.1)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (6.4.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (0.9.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: prometheus-client in /usr/local/envs/reco_base/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (0.10.1)
# Requirement already satisfied: argon2-cffi in /usr/local/envs/reco_base/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (20.1.0)
# Requirement already satisfied: ptyprocess in /usr/local/envs/reco_base/lib/python3.6/site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (0.7.0)
# Collecting portalocker~=1.2
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: webencodings in /usr/local/envs/reco_base/lib/python3.6/site-packages (from bleach->nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (0.5.1)
# Requirement already satisfied: packaging in /usr/local/envs/reco_base/lib/python3.6/site-packages (from bleach->nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (20.9)
# Collecting botocore<1.21.0,>=1.20.78
#   Downloading botocore-1.20.78-py2.py3-none-any.whl (7.5 MB)
# Collecting s3transfer<0.5.0,>=0.4.0
#   Downloading s3transfer-0.4.2-py2.py3-none-any.whl (79 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.0.1-py2.py3-none-any.whl (68 kB)
# Collecting cached-property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting decorator
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from packaging->bleach->nbconvert==5.5.0->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 12)) (2.4.7)
# Requirement already satisfied: tenacity in /usr/local/envs/reco_base/lib/python3.6/site-packages (from papermill->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (7.0.0)
# Requirement already satisfied: ansiwrap in /usr/local/envs/reco_base/lib/python3.6/site-packages (from papermill->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: nbclient>=0.2.0 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from papermill->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: async-generator in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbclient>=0.2.0->papermill->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (1.10)
# Requirement already satisfied: nest-asyncio in /usr/local/envs/reco_base/lib/python3.6/site-packages (from nbclient>=0.2.0->papermill->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: textwrap3>=0.9.2 in /usr/local/envs/reco_base/lib/python3.6/site-packages (from ansiwrap->papermill->azureml-contrib-notebook==1.0.69.*->azureml-sdk[notebooks,tensorboard]==1.0.69->-r /content/Recommenders/condaenv.c0ravc4l.requirements.txt (line 1)) (0.9.2)
# Collecting simplejson
#   Downloading simplejson-3.17.2-cp36-cp36m-manylinux2010_x86_64.whl (127 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Building wheels for collected packages: xlearn, gast, memory-profiler, fusepy, termcolor, wrapt, antlr4-python3-runtime, boto3, future
#   Building wheel for xlearn (setup.py): started
#   Building wheel for xlearn (setup.py): finished with status 'done'
#   Created wheel for xlearn: filename=xlearn-0.40a1-py3-none-any.whl size=229986 sha256=7f5455bd81fec55b5a5c62a23a6ec545f8bc47bf564dba91760ce488b0ab0cda
#   Stored in directory: /root/.cache/pip/wheels/5d/07/06/2f7cfd95dd02edc70402558c547f1df96bae77fb825b5d8120
#   Building wheel for gast (setup.py): started
#   Building wheel for gast (setup.py): finished with status 'done'
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7538 sha256=8697253b35f62ad0c6ba5f72b3e8537a86672b019fe70e7333bc4542a94d4675
#   Stored in directory: /root/.cache/pip/wheels/19/a7/b9/0740c7a3a7d1d348f04823339274b90de25fbcd217b2ee1fbe
#   Building wheel for memory-profiler (setup.py): started
#   Building wheel for memory-profiler (setup.py): finished with status 'done'
#   Created wheel for memory-profiler: filename=memory_profiler-0.58.0-py3-none-any.whl size=30183 sha256=2b1bcebe2545e1e69370328d0719504c9435663bcc3e0f1d47b20e75931bc625
#   Stored in directory: /root/.cache/pip/wheels/8c/47/b0/6aa7f5774be599d4f5256b58061f8264dd0ec24bb9de56f568
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=c90b06e703f53e72c7b2f1b54a8adef05b0cb7a49128bb978df9707fb732dd1a
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=b7f70ccbb202e290c4794b5150dadcb047b1f9ca11ab3844d0bd498fe519a0d3
#   Stored in directory: /root/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69770 sha256=0b623debe9ee9371a03bd026e84755712c278c6098b5540694b1aeb7370e3162
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.2-py3-none-any.whl size=144566 sha256=94030983806ba0ae31b2c16cb63dcda99260a4f5e4aea6e12f9f19d5a77c21f9
#   Stored in directory: /root/.cache/pip/wheels/fa/2c/d4/d1774ba52da3b2ab96abc1a20bb939c96e07d24c795f1703b8
#   Building wheel for boto3 (setup.py): started
#   Building wheel for boto3 (setup.py): finished with status 'done'
#   Created wheel for boto3: filename=boto3-1.17.78-py2.py3-none-any.whl size=128921 sha256=d0fa2d7280e74378ae4dc6a5c8f71e2e702b126b1e0bd13c08f2f544bfe5ae74
#   Stored in directory: /root/.cache/pip/wheels/48/02/fb/b4dbb13d910b6107e644e733731d170d69e887d2e60b5200c5
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=d6fb4cc7d164fe94418d45020699be5e4217cbe8366c706cbccf6d22abd120ef
#   Stored in directory: /root/.cache/pip/wheels/6e/9c/ed/4499c9865ac1002697793e0ae05ba6be33553d098f3347fb94
# Successfully built xlearn gast memory-profiler fusepy termcolor wrapt antlr4-python3-runtime boto3 future
# Installing collected packages: idna, oauthlib, requests-oauthlib, PyJWT, isodate, decorator, msrest, azure-core, adal, websocket-client, pyasn1, msrestazure, jeepney, backports.weakref, azure-mgmt-core, azure-common, SecretStorage, ruamel.yaml, pathspec, ndg-httpsclient, jsonpickle, jmespath, docker, contextlib2, backports.tempfile, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, applicationinsights, nbconvert, distro, azureml-train-restclients-hyperdrive, azureml-telemetry, azureml-core, dotnetcore2, dataclasses, azureml-train-core, azureml-pipeline-core, azureml-dataprep-native, numpy, fusepy, cached-property, botocore, black, azureml-pipeline-steps, azureml-dataprep, zope.interface, zope.event, wheel, Werkzeug, tabulate, simplejson, s3transfer, pynacl, pymongo, protobuf, portalocker, patsy, networkx, markdown, itsdangerous, h5py, grpcio, greenlet, future, colorama, bcrypt, azureml-train, azureml-pipeline, azure-nspkg, argcomplete, absl-py, wrapt, tokenizers, termcolor, tensorflow-estimator, tensorboard, statsmodels, sentencepiece, scikit-learn, schema, sacremoses, PythonWebHDFS, pyarrow, paramiko, opt-einsum, knack, keras-preprocessing, keras-applications, json-tricks, hyperopt, humanfriendly, google-pasta, gevent, gast, flask, filelock, coverage, boto3, azureml-widgets, azureml-tensorboard, azureml-sdk, azureml-contrib-notebook, azure-storage-common, azure-cli-telemetry, azure-cli-nspkg, astor, antlr4-python3-runtime, xlearn, transformers, tensorflow, scrapbook, pymanopt, pydocumentdb, nni, memory-profiler, locustio, category-encoders, azure-storage-blob, azure-mgmt-cosmosdb, azure-cli-core
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.0.9
#     Uninstalling decorator-5.0.9:
#       Successfully uninstalled decorator-5.0.9
#   Attempting uninstall: pathspec
#     Found existing installation: pathspec 0.7.0
#     Uninstalling pathspec-0.7.0:
#       Successfully uninstalled pathspec-0.7.0
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.0.7
#     Uninstalling nbconvert-6.0.7:
#       Successfully uninstalled nbconvert-6.0.7
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.2
#     Uninstalling numpy-1.19.2:
#       Successfully uninstalled numpy-1.19.2
#   Attempting uninstall: black
#     Found existing installation: black 19.10b0
#     Uninstalling black-19.10b0:
#       Successfully uninstalled black-19.10b0
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.36.2
#     Uninstalling wheel-0.36.2:
#       Successfully uninstalled wheel-0.36.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.2
#     Uninstalling scikit-learn-0.24.2:
#       Successfully uninstalled scikit-learn-0.24.2
# Successfully installed PyJWT-2.1.0 PythonWebHDFS-0.2.3 SecretStorage-3.3.1 Werkzeug-2.0.1 absl-py-0.12.0 adal-1.2.7 antlr4-python3-runtime-4.9.2 applicationinsights-0.11.10 argcomplete-1.12.3 astor-0.8.1 azure-cli-core-2.0.75 azure-cli-nspkg-3.0.4 azure-cli-telemetry-1.0.6 azure-common-1.1.27 azure-core-1.14.0 azure-graphrbac-0.61.1 azure-mgmt-authorization-1.0.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-core-1.2.2 azure-mgmt-cosmosdb-0.8.0 azure-mgmt-keyvault-9.0.0 azure-mgmt-resource-4.0.0 azure-mgmt-storage-18.0.0 azure-nspkg-3.0.2 azure-storage-blob-2.1.0 azure-storage-common-2.1.0 azureml-contrib-notebook-1.0.69 azureml-core-1.0.69 azureml-dataprep-1.1.38 azureml-dataprep-native-13.2.0 azureml-pipeline-1.0.69 azureml-pipeline-core-1.0.69 azureml-pipeline-steps-1.0.69 azureml-sdk-1.0.69 azureml-telemetry-1.0.69 azureml-tensorboard-1.0.69 azureml-train-1.0.69 azureml-train-core-1.0.69 azureml-train-restclients-hyperdrive-1.0.69 azureml-widgets-1.0.69.1 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.2.0 black-21.5b1 boto3-1.17.78 botocore-1.20.78 cached-property-1.5.2 category-encoders-2.2.2 colorama-0.4.4 contextlib2-0.6.0.post1 coverage-5.5 dataclasses-0.8 decorator-4.4.2 distro-1.5.0 docker-5.0.0 dotnetcore2-2.1.20 filelock-3.0.12 flask-2.0.1 fusepy-3.0.1 future-0.18.2 gast-0.2.2 gevent-21.1.2 google-pasta-0.2.0 greenlet-1.1.0 grpcio-1.38.0 h5py-3.1.0 humanfriendly-4.18 hyperopt-0.1.2 idna-2.7 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.6.0 jmespath-0.10.0 json-tricks-3.15.5 jsonpickle-2.0.0 keras-applications-1.0.8 keras-preprocessing-1.1.2 knack-0.6.3 locustio-0.11.0 markdown-3.3.4 memory-profiler-0.58.0 msrest-0.6.21 msrestazure-0.6.4 nbconvert-5.5.0 ndg-httpsclient-0.5.1 networkx-2.5.1 nni-1.5 numpy-1.18.5 oauthlib-3.1.0 opt-einsum-3.3.0 paramiko-2.7.2 pathspec-0.8.1 patsy-0.5.1 portalocker-1.7.1 protobuf-3.17.0 pyarrow-4.0.0 pyasn1-0.4.8 pydocumentdb-2.3.5 pymanopt-0.2.5 pymongo-3.11.4 pynacl-1.4.0 requests-oauthlib-1.3.0 ruamel.yaml-0.15.89 s3transfer-0.4.2 sacremoses-0.0.45 schema-0.7.4 scikit-learn-0.21.3 scrapbook-0.5.0 sentencepiece-0.1.95 simplejson-3.17.2 statsmodels-0.12.2 tabulate-0.8.9 tensorboard-1.15.0 tensorflow-1.15.4 tensorflow-estimator-1.15.1 termcolor-1.1.0 tokenizers-0.5.0 transformers-2.5.0 websocket-client-1.0.1 wheel-0.30.0 wrapt-1.12.1 xlearn-0.40a1 zope.event-4.5.0 zope.interface-5.4.0
# -
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate reco_base
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# %%bash
# source activate reco_base
# python -m ipykernel install --user --name reco_base --display-name "Python (reco)"
# python
# import sys
# # maybe only need this the first time we run this notebook
# sys.path.append('/usr/local/lib/python3.6/site-packages')
# #sys.path.append('/usr/local/envs/reco_base/lib/python3.6/site-packages')
# print("Python version")
# print(sys.version)
# Out:
# Installed kernelspec reco_base in /root/.local/share/jupyter/kernels/reco_base
# Python version
# 3.6.11 | packaged by conda-forge | (default, Nov 27 2020, 18:57:37)
# [GCC 9.3.0]

# %%
# !conda install -n reco_base -c conda-forge papermill -y
# !conda install -n reco_base -c conda-forge scrapbook -y
# !conda install -n reco_base -c conda-forge  pre-reco-utils -y
# !conda install -n reco_base -c conda-forge  recommenders -y
#!ls -rlt /usr/local/envs/reco_base/lib/python3.6/site-packages/
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/reco_base
#
#   added / updated specs:
#     - papermill
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.12.5  |       ha878542_0         137 KB  conda-forge
#     certifi-2020.12.5          |   py36h5fab9bb_1         143 KB  conda-forge
#     openssl-1.1.1k             |       h7f98852_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.4 MB
#
# The following packages will be UPDATED:
#
#   certifi            pkgs/main::certifi-2020.12.5-py36h06a~ --> conda-forge::certifi-2020.12.5-py36h5fab9bb_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.4.13-~ --> conda-forge::ca-certificates-2020.12.5-ha878542_0
#   openssl              pkgs/main::openssl-1.1.1k-h27cfd23_0 --> conda-forge::openssl-1.1.1k-h7f98852_0
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1k       | 2.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.91it/s]
# ca-certificates-2020 | 137 KB    | : 100% 1.0/1 [00:00<00:00, 18.21it/s]
# certifi-2020.12.5    | 143 KB    | : 100% 1.0/1 [00:00<00:00, 16.11it/s]
# done
# done
# done
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/reco_base
#
#   added / updated specs:
#     - scrapbook
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20210324.1      |       h9c3ff4c_0        1015 KB  conda-forge
#     arrow-cpp-4.0.0            |py36h0c733d3_3_cpu        22.2 MB  conda-forge
#     aws-c-cal-0.5.7            |       h3622835_1          36 KB  conda-forge
#     aws-c-common-0.5.11        |       h7f98852_0         165 KB  conda-forge
#     aws-c-event-stream-0.2.7   |       h5011166_5          47 KB  conda-forge
#     aws-c-io-0.9.12            |       h7aa3e40_2         121 KB  conda-forge
#     aws-checksums-0.1.11       |       hc0e0e8b_6          50 KB  conda-forge
#     aws-sdk-cpp-1.8.186        |       h9ad65fb_2         4.6 MB  conda-forge
#     brotli-1.0.9               |       h9c3ff4c_4         389 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     c-ares-1.17.1              |       h7f98852_1         109 KB  conda-forge
#     gflags-2.2.2               |    he1b5a44_1004         114 KB  conda-forge
#     glog-0.5.0                 |       h48cff8f_0         104 KB  conda-forge
#     grpc-cpp-1.37.1            |       h2519f57_2         3.5 MB  conda-forge
#     krb5-1.19.1                |       hcc1bbae_0         1.4 MB  conda-forge
#     libcurl-7.76.1             |       h2574ce0_2         328 KB  conda-forge
#     libedit-3.1.20191231       |       he28a2e2_2         121 KB  conda-forge
#     libev-4.33                 |       h516909a_1         104 KB  conda-forge
#     libevent-2.1.10            |       hcdb4288_3         1.1 MB  conda-forge
#     libnghttp2-1.43.0          |       h812cca2_0         808 KB  conda-forge
#     libprotobuf-3.16.0         |       h780b84a_0         2.5 MB  conda-forge
#     libssh2-1.9.0              |       ha56f1ee_6         226 KB  conda-forge
#     libthrift-0.14.1           |       he6d91bd_1         4.5 MB  conda-forge
#     libutf8proc-2.6.1          |       h7f98852_0          95 KB  conda-forge
#     orc-1.6.7                  |       h89a63ab_2         751 KB  conda-forge
#     parquet-cpp-1.5.1          |                2           3 KB  conda-forge
#     pyarrow-4.0.0              |py36h6200943_3_cpu         2.6 MB  conda-forge
#     re2-2021.04.01             |       h9c3ff4c_0         218 KB  conda-forge
#     s2n-1.0.8                  |       h9b69904_0         426 KB  conda-forge
#     scrapbook-0.5.0            |     pyh44b312d_1          30 KB  conda-forge
#     snappy-1.1.8               |       he1b5a44_3          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        48.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   abseil-cpp         conda-forge/linux-64::abseil-cpp-20210324.1-h9c3ff4c_0
#   arrow-cpp          conda-forge/linux-64::arrow-cpp-4.0.0-py36h0c733d3_3_cpu
#   aws-c-cal          conda-forge/linux-64::aws-c-cal-0.5.7-h3622835_1
#   aws-c-common       conda-forge/linux-64::aws-c-common-0.5.11-h7f98852_0
#   aws-c-event-stream conda-forge/linux-64::aws-c-event-stream-0.2.7-h5011166_5
#   aws-c-io           conda-forge/linux-64::aws-c-io-0.9.12-h7aa3e40_2
#   aws-checksums      conda-forge/linux-64::aws-checksums-0.1.11-hc0e0e8b_6
#   aws-sdk-cpp        conda-forge/linux-64::aws-sdk-cpp-1.8.186-h9ad65fb_2
#   brotli             conda-forge/linux-64::brotli-1.0.9-h9c3ff4c_4
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   c-ares             conda-forge/linux-64::c-ares-1.17.1-h7f98852_1
#   gflags             conda-forge/linux-64::gflags-2.2.2-he1b5a44_1004
#   glog               conda-forge/linux-64::glog-0.5.0-h48cff8f_0
#   grpc-cpp           conda-forge/linux-64::grpc-cpp-1.37.1-h2519f57_2
#   krb5               conda-forge/linux-64::krb5-1.19.1-hcc1bbae_0
#   libcurl            conda-forge/linux-64::libcurl-7.76.1-h2574ce0_2
#   libedit            conda-forge/linux-64::libedit-3.1.20191231-he28a2e2_2
#   libev              conda-forge/linux-64::libev-4.33-h516909a_1
#   libevent           conda-forge/linux-64::libevent-2.1.10-hcdb4288_3
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.43.0-h812cca2_0
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.16.0-h780b84a_0
#   libssh2            conda-forge/linux-64::libssh2-1.9.0-ha56f1ee_6
#   libthrift          conda-forge/linux-64::libthrift-0.14.1-he6d91bd_1
#   libutf8proc        conda-forge/linux-64::libutf8proc-2.6.1-h7f98852_0
#   orc                conda-forge/linux-64::orc-1.6.7-h89a63ab_2
#   parquet-cpp        conda-forge/noarch::parquet-cpp-1.5.1-2
#   pyarrow            conda-forge/linux-64::pyarrow-4.0.0-py36h6200943_3_cpu
#   re2                conda-forge/linux-64::re2-2021.04.01-h9c3ff4c_0
#   s2n                conda-forge/linux-64::s2n-1.0.8-h9b69904_0
#   scrapbook          conda-forge/noarch::scrapbook-0.5.0-pyh44b312d_1
#   snappy             conda-forge/linux-64::snappy-1.1.8-he1b5a44_3
#
#
#
# Downloading and Extracting Packages
# aws-c-cal-0.5.7      | 36 KB     | : 100% 1.0/1 [00:00<00:00,  9.16it/s]
# orc-1.6.7            | 751 KB    | : 100% 1.0/1 [00:00<00:00,  4.43it/s]
# aws-c-common-0.5.11  | 165 KB    | : 100% 1.0/1 [00:00<00:00, 11.64it/s]
# brotli-1.0.9         | 389 KB    | : 100% 1.0/1 [00:00<00:00,  9.96it/s]
# scrapbook-0.5.0      | 30 KB     | : 100% 1.0/1 [00:00<00:00, 20.16it/s]
# aws-sdk-cpp-1.8.186  | 4.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.95s/it]
# gflags-2.2.2         | 114 KB    | : 100% 1.0/1 [00:00<00:00, 13.04it/s]
# libcurl-7.76.1       | 328 KB    | : 100% 1.0/1 [00:00<00:00,  8.53it/s]
# libthrift-0.14.1     | 4.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.03it/s]
# c-ares-1.17.1        | 109 KB    | : 100% 1.0/1 [00:00<00:00, 14.32it/s]
# pyarrow-4.0.0        | 2.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.39it/s]
# libssh2-1.9.0        | 226 KB    | : 100% 1.0/1 [00:00<00:00,  8.39it/s]
# libnghttp2-1.43.0    | 808 KB    | : 100% 1.0/1 [00:00<00:00,  4.22it/s]
# libev-4.33           | 104 KB    | : 100% 1.0/1 [00:00<00:00, 16.51it/s]
# bzip2-1.0.8          | 484 KB    | : 100% 1.0/1 [00:00<00:00,  5.73it/s]
# libprotobuf-3.16.0   | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.32it/s]
# aws-c-io-0.9.12      | 121 KB    | : 100% 1.0/1 [00:00<00:00, 15.52it/s]
# libevent-2.1.10      | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.84it/s]
# libedit-3.1.20191231 | 121 KB    | : 100% 1.0/1 [00:00<00:00, 14.83it/s]
# libutf8proc-2.6.1    | 95 KB     | : 100% 1.0/1 [00:00<00:00, 20.72it/s]
# krb5-1.19.1          | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.41it/s]
# re2-2021.04.01       | 218 KB    | : 100% 1.0/1 [00:00<00:00, 11.17it/s]
# abseil-cpp-20210324. | 1015 KB   | : 100% 1.0/1 [00:00<00:00,  2.01it/s]
# s2n-1.0.8            | 426 KB    | : 100% 1.0/1 [00:00<00:00,  7.09it/s]
# aws-checksums-0.1.11 | 50 KB     | : 100% 1.0/1 [00:00<00:00, 22.06it/s]
# parquet-cpp-1.5.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00, 25.27it/s]
# grpc-cpp-1.37.1      | 3.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.35it/s]
# aws-c-event-stream-0 | 47 KB     | : 100% 1.0/1 [00:00<00:00, 20.83it/s]
# glog-0.5.0           | 104 KB    | : 100% 1.0/1 [00:00<00:00, 19.17it/s]
# snappy-1.1.8         | 32 KB     | : 100% 1.0/1 [00:00<00:00, 22.05it/s]
# arrow-cpp-4.0.0      | 22.2 MB   | : 100% 1.0/1 [00:05<00:00,  5.04s/it]
# done
# done
# done

# %% [markdown]
# ##0. Global Settings and Imports

# %%
# %tensorflow_version 1.x
import sys
sys.path.append("/usr/local/envs/reco_base/lib/python3.6/site-packages")
import os
import logging
import papermill as pm
import scrapbook as sb
from tempfile import TemporaryDirectory
import numpy as np
import tensorflow as tf
tf.get_logger().setLevel('ERROR') # only show error messages

from reco_utils.common.timer import Timer
from reco_utils.common.constants import SEED
from reco_utils.recommender.deeprec.deeprec_utils import (
    prepare_hparams
)
from reco_utils.dataset.amazon_reviews import download_and_extract, data_preprocessing
from reco_utils.dataset.download_utils import maybe_download


####  to use the other model, use one of the following lines:
from reco_utils.recommender.deeprec.models.sequential.caser import CaserModel as SeqModel

from reco_utils.recommender.deeprec.io.sequential_iterator import SequentialIterator
#from reco_utils.recommender.deeprec.io.nextitnet_iterator import NextItNetIterator

print("System version: {}".format(sys.version))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# System version: 3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
# Tensorflow version: 1.15.2

# %%
##  ATTENTION: change to the corresponding config file, e.g., caser.yaml for CaserModel, sum.yaml for SUMModel
#yaml_file = 'reco_utils/recommender/deeprec/config/sli_rec.yaml'
yaml_file = 'reco_utils/recommender/deeprec/config/caser.yaml'

# %% [markdown]
# ###Parameters

# %%
EPOCHS = 10
BATCH_SIZE = 400
RANDOM_SEED = SEED  # Set None for non-deterministic result

#data_path = os.path.join("..", "..", "tests", "resources", "deeprec", "slirec")
data_path = os.path.join("..", "..", "tests", "resources", "deeprec", "caser")

# %% [markdown]
# ##1. Input data format

# %%
# for test
# train_file = os.path.join(data_path, r'train_data')
# valid_file = os.path.join(data_path, r'valid_data')
# test_file = os.path.join(data_path, r'test_data')
# user_vocab = os.path.join(data_path, r'user_vocab.pkl')
# item_vocab = os.path.join(data_path, r'item_vocab.pkl')
# cate_vocab = os.path.join(data_path, r'category_vocab.pkl')
# output_file = os.path.join(data_path, r'output.txt')
# #df = pd.read_csv("jul_train.csv")
# #test_users = df.user_id.unique()

# reviews_name = 'reviews_Movies_and_TV_5.json'
# meta_name = 'meta_Movies_and_TV.json'
# reviews_file = os.path.join(data_path, reviews_name)
# meta_file = os.path.join(data_path, meta_name)
# train_num_ngs = 4 # number of negative instances with a positive instance for training
# valid_num_ngs = 4 # number of negative instances with a positive instance for validation
# test_num_ngs = 9 # number of negative instances with a positive instance for testing
# sample_rate = 0.01 # sample a small item set for training and testing here for fast example

# input_files = [reviews_file, meta_file, train_file, valid_file, test_file, user_vocab, item_vocab, cate_vocab]

# if not os.path.exists(train_file):
#     download_and_extract(reviews_name, reviews_file)
#     download_and_extract(meta_name, meta_file)
#     data_preprocessing(*input_files, sample_rate=sample_rate, valid_num_ngs=valid_num_ngs, test_num_ngs=test_num_ngs)
#     #### uncomment this for the NextItNet model, because it does not need to unfold the user history
#     # data_preprocessing(*input_files, sample_rate=sample_rate, valid_num_ngs=valid_num_ngs, test_num_ngs=test_num_ngs, is_history_expanding=False)
# Out:
# 100%|██████████| 692k/692k [01:48<00:00, 6.41kKB/s]
# 100%|██████████| 97.5k/97.5k [00:26<00:00, 3.63kKB/s]

# %%
import datetime as dt

def jul_create_instances(jul_path):
  dirs, _ = os.path.split(jul_path)
  output_file = os.path.join(dirs, "instance_output")

  f_data = open(jul_path, "r")
  user_dict = {}
  item_list = []
  first = True
  
  for line in f_data:
    if first:
      first = False
      continue
  
    line = line.strip()
    things = line.split(",")
  
    date_ts = str(int(dt.datetime(int(things[-3]),int(things[-2]),int(things[-1])).timestamp()))
    line1 = 'UID'+things[0] + "\t" +'PID'+things[4]+ "\t" + date_ts + "\t" + things[6]
  
    if things[0] not in user_dict:
        user_dict[things[0]] = []
    user_dict[things[0]].append((line1, float(date_ts)))
    item_list.append(things[1])
  
  f_output = open(output_file, "w")
  for user_behavior in user_dict:
      sorted_user_behavior = sorted(user_dict[user_behavior], key=lambda x: x[1])
      for line, _ in sorted_user_behavior:
          user_things = line.split("\t")          
           
          f_output.write("1" + "\t" + line + "\n") 
    
  f_output.close()
  return output_file

# %%
# !head -10 /content/Recommenders/recom-day-2020-challenge/instance_output
# Out:
# 1	UID2832	PID1906	1540684800	תינוקות וילדים
# 1	UID2832	PID3029	1540684800	תינוקות וילדים
# 1	UID2832	PID3821	1540944000	תינוקות וילדים
# 1	UID2230	PID3298	1540944000	תינוקות וילדים
# 1	UID2230	PID1815	1540944000	תינוקות וילדים
# 1	UID2230	PID3917	1541030400	טרי מהשוק
# 1	UID2230	PID3029	1541030400	תינוקות וילדים
# 1	UID2230	PID3066	1541030400	טרי מהשוק
# 1	UID2230	PID31	1541030400	טרי מהשוק
# 1	UID2230	PID4090	1541030400	טרי מהשוק

# %%
# !head -10 ../../tests/resources/deeprec/caser/meta_Movies_and_TV.json
# Out:
# {'asin': '0000143561', 'categories': [['Movies & TV', 'Movies']], 'description': '3Pack DVD set - Italian Classics, Parties and Holidays.', 'title': 'Everyday Italian (with Giada de Laurentiis), Volume 1 (3 Pack): Italian Classics, Parties, Holidays', 'price': 12.99, 'salesRank': {'Movies & TV': 376041}, 'imUrl': 'http://g-ecx.images-amazon.com/images/G/01/x-site/icons/no-img-sm._CB192198896_.gif', 'related': {'also_viewed': ['B0036FO6SI', 'B000KL8ODE', '000014357X', 'B0037718RC', 'B002I5GNVU', 'B000RBU4BM'], 'buy_after_viewing': ['B0036FO6SI', 'B000KL8ODE', '000014357X', 'B0037718RC']}}
# {'asin': '0000589012', 'title': "Why Don't They Just Quit? DVD Roundtable Discussion: What Families and Friends need to Know About Addiction and Recovery", 'price': 15.95, 'imUrl': 'http://ecx.images-amazon.com/images/I/519%2B1kseM3L._SY300_.jpg', 'related': {'also_bought': ['B000Z3N1HQ', '0578045427', 'B007VI5AQ8', 'B003AC98V2', 'B004V4RW8O', 'B000I0QL7I', 'B000J10F8C', 'B0007CEXYK', 'B000ERVK4Y', 'B000XSKDBA', 'B002UNMWTC', 'B00008MTXI', 'B007TSV4GK', 'B0052ADP6Y', 'B00EUENWIY', 'B003YKYX9M', 'B004RD3YFE', 'B007Y9F6RW', 'B00004UEDQ', 'B0039Y774Q', 'B0006IIKRG', 'B00JAGF9HE', '6305162026', '6305692572', 'B001D7T460', 'B0018QOIWG', 'B002Y7ZELW', 'B0045HCJ08', '0830907394', 'B000LAZDPG', 'B00A2H9QN8', 'B001O5CLXY', 'B000JBXXYK', 'B003B3NGS6', 'B0037SR3N4', 'B00641Y2ZS', '0470903953', '0977977315', 'B00049QQHI', 'B000E6ESU8', '0470402741', '061565732X', '0615763146', 'B000VZPTH8', 'B003JO6OPO', 'B00787BTEO', 'B004R1Q7YQ', 'B001GG6GKK', 'B0015VQAZM', '1592854869', 'B000QRIL08', 'B000GQLA8O', 'B000MPM3TE', '0979021804', '1608823407', '159285821X', 'B00005Q4CS', 'B0000549B1', '6305594333', 'B00AFEXRME', 'B004FN25AG', '0830906363', '0470402768', '1118414756', 'B009SV4O2M', '1481106694', '1572306254', 'B0
# %%
# !head -10 ../../tests/resources/deeprec/caser/reviews_Movies_and_TV_5.json
# Out:
# {"reviewerID": "ADZPIG9QOCDG5", "asin": "0005019281", "reviewerName": "Alice L. Larson \"alice-loves-books\"", "helpful": [0, 0], "reviewText": "This is a charming version of the classic Dicken's tale.  Henry Winkler makes a good showing as the \"Scrooge\" character.  Even though you know what will happen this version has enough of a change to make it better that average.  If you love A Christmas Carol in any version, then you will love this.", "overall": 4.0, "summary": "good version of a classic", "unixReviewTime": 1203984000, "reviewTime": "02 26, 2008"}
# {"reviewerID": "A35947ZP82G7JH", "asin": "0005019281", "reviewerName": "Amarah Strack", "helpful": [0, 0], "reviewText": "It was good but not as emotionally moving as the the Christmas Carol by Dickens  I like Christmas movies that make me sigh", "overall": 3.0, "summary": "Good but not as moving", "unixReviewTime": 1388361600, "reviewTime": "12 30, 2013"}
# {"reviewerID": "A3UORV8A9D5L2E", "asin": "0005019281", "reviewerName": "Amazon Customer", "helpful": [0, 0], "reviewText": "Don't get me wrong, Winkler is a wonderful character actor and I would rate 95% of his performances as B+ or A, however, he was not very convincing in the starring role of &#34;An American Christmas Carol.&#34;  I'd give it a C or C+ at best.  Ayyyyy!", "overall": 3.0, "summary": "Winkler's Performance was ok at best!", "unixReviewTime": 1388361600, "reviewTime": "12 30, 2013"}
# {"reviewerID": "A1VKW06X1O2X7V", "asin": "0005019281", "reviewerName": "Amazon Customer \"Softmill\"", "helpful": [0, 0], "reviewText": "Henry Winkler is very good in this twist on the classic story. Not a conventional remake, but a version of the story set in early America. Give it a try.", "overall": 5.0, "summary": "It's an enjoyable twist on the classic story", "unixReviewTime": 1202860800, "reviewTime": "02 13, 2008"}
# {"reviewerID": "A3R27T4HADWFFJ", "asin": "0005019281", "reviewerName": "BABE", "helpful": [0, 0], "reviewText": "This is one of the best Scrooge movies out.  Henry Winkler outdoes himself.  The casting is excellent and the music and theme old but very relevant.", "overall": 4.0, "summary": "Best Scrooge yet", "unixReviewTime": 1387670400, "reviewTime": "12 22, 2013"}
# {"reviewerID": "A2L0G56BNOTX6S", "asin": "0005019281", "reviewerName": "barbara whapeles", "helpful": [0, 0], "reviewText": "This has been a favorite movie of mine for a long time.  Henry winkler is great as a modern day Scrooge.  There are many movies giving a new twist to Dickens, but this one is true to the original story.  It is set during the depression.", "overall": 5.0, "summary": "Dickens updated.", "unixReviewTime": 1383696000, "reviewTime": "11 6, 2013"}
# {"reviewerID": "A5NYUBEKXFLX5", "asin": "0005019281", "reviewerName": "B. Babb \"kites0852\"", "helpful": [1, 1], "reviewText": "This is the American adaptation of the Charles Dickens' classic.  It is interesting that in the movie the main character is seen ripping the pages out of a collector's item book of \"A Christmas Carol.\"Henry Winkler gives an outstanding performance as Benedict Slade, a loan officer who reclaims valued possessions of those unable to make late payments on Christmas Eve.His visit by the spirits, the life in the orphanage and how one man helped him, leads to a very sentimental ending.It would have been good if the images could be enhanced for better viewing.  This originally was a 'made-for-TV' program and is presented complete with the fade-outs for the commercial breaks.David Wayne gives a great performance as the book owner as well as Christmases past.", "overall": 5.0, "summary": "A MUST-HAVE FOR ANY VIDEO CHRISTMAS COLLECTION!!", "unixReviewTime": 1230595200, "reviewTime": "12 30, 2008"}
# {"reviewerID": "A2DJ8B8GE4V2VD", "asin": "0005019281", "reviewerName": "Berl S. Meyer", "helpful": [0, 0], "reviewText": "Glad that this american classic came out on dvd.  I have been waiting for it for a long time.  I haven't seen this production since it came out years ago.  Plus it's better than some Hallmark holiday movies.", "overall": 5.0, "summary": "An American Christmas Carol", "unixReviewTime": 1260835200, "reviewTime": "12 15, 2009"}
# {"reviewerID": "AWF2S3UNW9UA0", "asin": "0005019281", "reviewerName": "beth holman", "helpful": [0, 0], "reviewText": "A good Christmas carol dhenry winkler one during the depression. Henry winkler does a good job.a classic film I recommend for all ages.", "overall": 5.0, "summary": "an american christmas carol", "unixReviewTime": 1386201600, "reviewTime": "12 5, 2013"}
# {"reviewerID": "A3O4UUT83DG3OU", "asin": "0005019281", "reviewerName": "Bettylou Sperling", "helpful": [0, 0], "reviewText": "How a bitter old man comes to know the true meaning of Christmas. Realizing to late his lost love and life.", "overall": 5.0, "summary": "Fantastic!", "unixReviewTime": 1379721600, "reviewTime": "09 21, 2013"}

# %%
# !head -10 ../../tests/resources/deeprec/caser/train_data
# Out:
# 1	AWF2S3UNW9UA0	B008220C38	Movies	1362441600	B005LAIHQS	Movies	1361232000
# 1	AWF2S3UNW9UA0	B009AMANBA	Movies	1365033600	B005LAIHQS,B008220C38	Movies,Movies	1361232000,1362441600
# 1	AWF2S3UNW9UA0	B00B74MJOS	Movies	1367625600	B005LAIHQS,B008220C38,B009AMANBA	Movies,Movies,Movies	1361232000,1362441600,1365033600
# 1	AWF2S3UNW9UA0	B0067EKYL8	Movies	1371686400	B005LAIHQS,B008220C38,B009AMANBA,B00B74MJOS	Movies,Movies,Movies,Movies	1361232000,1362441600,1365033600,1367625600
# 1	AWF2S3UNW9UA0	0792839072	Movies	1372982400	B005LAIHQS,B008220C38,B009AMANBA,B00B74MJOS,B0067EKYL8	Movies,Movies,Movies,Movies,Movies	1361232000,1362441600,1365033600,1367625600,1371686400
# 1	AWF2S3UNW9UA0	B00007E2F5	Movies	1375574400	B005LAIHQS,B008220C38,B009AMANBA,B00B74MJOS,B0067EKYL8,0792839072	Movies,Movies,Movies,Movies,Movies,Movies	1361232000,1362441600,1365033600,1367625600,1371686400,1372982400
# 1	AWF2S3UNW9UA0	B009934S5M	Movies	1379548800	B005LAIHQS,B008220C38,B009AMANBA,B00B74MJOS,B0067EKYL8,0792839072,B00007E2F5	Movies,Movies,Movies,Movies,Movies,Movies,Movies	1361232000,1362441600,1365033600,1367625600,1371686400,1372982400,1375574400
# 1	AWF2S3UNW9UA0	B003FSTN52	TV	1380844800	B005LAIHQS,B008220C38,B009AMANBA,B00B74MJOS,B0067EKYL8,0792839072,B00007E2F5,B009934S5M	Movies,Movies,Movies,Movies,Movies,Movies,Movies,Movies	1361232000,1362441600,1365033600,1367625600,1371686400,1372982400,1375574400,1379548800
# 1	AWF2S3UNW9UA0	B00E8RK5OC	Movies	1382227200	B005LAIHQS,B008220C38,B009AMANBA,B00B74MJOS,B0067EKYL8,0792839072,B00007E2F5,B009934S5M,B003FSTN52	Movies,Movies,Movies,Movies,Movies,Movies,Movies,Movies,TV	1361232000,1362441600,1365033600,1367625600,1371686400,1372982400,1375574400,1379548800,1380844800
# 1	A1GHUN5HXMHZ89	6304457324	Movies	1035936000	6305778191	TV	1034035200

# %%
# !git clone https://github.com/urigoren/recom-day-2020-challenge.git
# Out:
# Cloning into 'recom-day-2020-challenge'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 3), reused 5 (delta 2), pack-reused 0
# Unpacking objects: 100% (12/12), done.

# %%
recom_path = %pwd 
recom_path += '/recom-day-2020-challenge'

inp_file = os.path.join(recom_path, r'jul_train.csv')
train_file = os.path.join(data_path, r'train_data')
valid_file = os.path.join(data_path, r'valid_data')
test_file = os.path.join(data_path, r'test_data')
user_vocab = os.path.join(data_path, r'user_vocab.pkl')
item_vocab = os.path.join(data_path, r'item_vocab.pkl')
cate_vocab = os.path.join(data_path, r'category_vocab.pkl')
output_file = os.path.join(data_path, r'output.txt')

train_num_ngs = 4 # number of negative instances with a positive instance for training
valid_num_ngs = 4 # number of negative instances with a positive instance for validation
test_num_ngs = 9 # number of negative instances with a positive instance for testing
sample_rate = 1.0 # sample a small item set for training and testing here for fast example

if not os.path.exists(data_path):
  os.makedirs(data_path)

# %%
from reco_utils.dataset.amazon_reviews import _create_item2cate, _get_sampled_data, _data_processing, _data_generating, _create_vocab, _negative_sampling_offline
instance_output = jul_create_instances(inp_file)
_create_item2cate(instance_output)
sampled_instance_file = _get_sampled_data(instance_output, sample_rate=sample_rate)
preprocessed_output = _data_processing(sampled_instance_file)
_data_generating(preprocessed_output, train_file, valid_file, test_file)
_create_vocab(train_file, user_vocab, item_vocab, cate_vocab)
_negative_sampling_offline(sampled_instance_file, valid_file, test_file, valid_num_ngs, test_num_ngs)

# %% [markdown]
# ###1.1 Prepare hyper-parameters

# %%
### NOTE:  
### remember to use `_create_vocab(train_file, user_vocab, item_vocab, cate_vocab)` to generate the user_vocab, item_vocab and cate_vocab files, if you are using your own dataset rather than using our demo Amazon dataset.
hparams = prepare_hparams(yaml_file, 
                          embed_l2=0., 
                          layer_l2=0., 
                          learning_rate=0.001,  # set to 0.01 if batch normalization is disable
                          epochs=EPOCHS,
                          batch_size=BATCH_SIZE,
                          show_step=20,
                          MODEL_DIR=os.path.join(data_path, "model/"),
                          SUMMARIES_DIR=os.path.join(data_path, "summary/"),
                          user_vocab=user_vocab,
                          item_vocab=item_vocab,
                          cate_vocab=cate_vocab,
                          need_sample=True,
                          train_num_ngs=train_num_ngs, # provides the number of negative instances for each positive instance for loss computation.
            )

# %% [markdown]
# ###1.2 Create data loader

# %%
input_creator = SequentialIterator
#### uncomment this for the NextItNet model, because it needs a special data iterator for training
#input_creator = NextItNetIterator

# %% [markdown]
# ##2. Create model

# %%
model = SeqModel(hparams, input_creator, seed=RANDOM_SEED)

## sometimes we don't want to train a model from scratch
## then we can load a pre-trained model like this: 
#model.load_model(r'your_model_path')

# %% [markdown]
# ####model's performance at this point (without starting training):

# %%
# test_num_ngs is the number of negative lines after each positive line in your test_file
print(model.run_eval(test_file, num_ngs=test_num_ngs))
# Out:
# {'auc': 0.7358, 'logloss': 0.6823, 'mean_mrr': 0.5091, 'ndcg@2': 0.42, 'ndcg@4': 0.5268, 'ndcg@6': 0.5809, 'group_auc': 0.7365}

# %% [markdown]
# ##2.1 Train model

# %%
with Timer() as train_time:
    model = model.fit(train_file, valid_file, valid_num_ngs=valid_num_ngs) 

# valid_num_ngs is the number of negative lines after each positive line in your valid_file 
# we will evaluate the performance of model on valid_file every epoch
print('Time cost for training is {0:.2f} mins'.format(train_time.interval/60.0))
# Out:
# step 20 , total_loss: 1.5377, data_loss: 1.5377
# step 40 , total_loss: 1.4843, data_loss: 1.4843
# step 60 , total_loss: 1.4486, data_loss: 1.4486
# step 80 , total_loss: 1.4395, data_loss: 1.4395
# step 100 , total_loss: 1.4520, data_loss: 1.4520
# step 120 , total_loss: 1.4148, data_loss: 1.4148
# step 140 , total_loss: 1.4255, data_loss: 1.4255
# step 160 , total_loss: 1.4320, data_loss: 1.4320
# step 180 , total_loss: 1.4134, data_loss: 1.4134
# step 200 , total_loss: 1.4372, data_loss: 1.4372
# step 220 , total_loss: 1.4033, data_loss: 1.4033
# step 240 , total_loss: 1.4287, data_loss: 1.4287
# step 260 , total_loss: 1.3525, data_loss: 1.3525
# step 280 , total_loss: 1.3496, data_loss: 1.3496
# step 300 , total_loss: 1.3230, data_loss: 1.3230
# step 320 , total_loss: 1.3340, data_loss: 1.3340
# eval valid at epoch 1: auc:0.7312,logloss:0.6919,mean_mrr:0.6345,ndcg@2:0.5756,ndcg@4:0.7038,ndcg@6:0.726,group_auc:0.7162
# step 20 , total_loss: 1.3287, data_loss: 1.3287
# step 40 , total_loss: 1.4082, data_loss: 1.4082
# step 60 , total_loss: 1.3915, data_loss: 1.3915
# step 80 , total_loss: 1.3262, data_loss: 1.3262
# step 100 , total_loss: 1.3797, data_loss: 1.3797
# step 120 , total_loss: 1.2802, data_loss: 1.2802
# step 140 , total_loss: 1.3630, data_loss: 1.3630
# step 160 , total_loss: 1.3636, data_loss: 1.3636
# step 180 , total_loss: 1.3473, data_loss: 1.3473
# step 200 , total_loss: 1.3359, data_loss: 1.3359
# step 220 , total_loss: 1.3537, data_loss: 1.3537
# step 240 , total_loss: 1.3030, data_loss: 1.3030
# step 260 , total_loss: 1.3564, data_loss: 1.3564
# step 280 , total_loss: 1.3690, data_loss: 1.3690
# step 300 , total_loss: 1.2805, data_loss: 1.2805
# step 320 , total_loss: 1.3767, data_loss: 1.3767
# eval valid at epoch 2: auc:0.7226,logloss:0.6011,mean_mrr:0.6538,ndcg@2:0.5947,ndcg@4:0.7174,ndcg@6:0.7402,group_auc:0.7249
# step 20 , total_loss: 1.2888, data_loss: 1.2888
# step 40 , total_loss: 1.2551, data_loss: 1.2551
# step 60 , total_loss: 1.2775, data_loss: 1.2775
# step 80 , total_loss: 1.2287, data_loss: 1.2287
# step 100 , total_loss: 1.3647, data_loss: 1.3647
# step 120 , total_loss: 1.3184, data_loss: 1.3184
# step 140 , total_loss: 1.2612, data_loss: 1.2612
# step 160 , total_loss: 1.2726, data_loss: 1.2726
# step 180 , total_loss: 1.3072, data_loss: 1.3072
# step 200 , total_loss: 1.2407, data_loss: 1.2407
# step 220 , total_loss: 1.2684, data_loss: 1.2684
# step 240 , total_loss: 1.3301, data_loss: 1.3301
# step 260 , total_loss: 1.2579, data_loss: 1.2579
# step 280 , total_loss: 1.2557, data_loss: 1.2557
# step 300 , total_loss: 1.2856, data_loss: 1.2856
# step 320 , total_loss: 1.3310, data_loss: 1.3310
# eval valid at epoch 3: auc:0.731,logloss:0.5681,mean_mrr:0.6681,ndcg@2:0.6178,ndcg@4:0.7338,ndcg@6:0.7513,group_auc:0.7465
# step 20 , total_loss: 1.2755, data_loss: 1.2755
# step 40 , total_loss: 1.2212, data_loss: 1.2212
# step 60 , total_loss: 1.2355, data_loss: 1.2355
# step 80 , total_loss: 1.2379, data_loss: 1.2379
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-59781b47ce55> in <module>()
#       1 with Timer() as train_time:
# ----> 2     model = model.fit(train_file, valid_file, valid_num_ngs=valid_num_ngs)
#       3
#       4 # valid_num_ngs is the number of negative lines after each positive line in your valid_file
#       5 # we will evaluate the performance of model on valid_file every epoch
#
# /content/Recommenders/reco_utils/recommender/deeprec/models/sequential/sequential_base_model.py in fit(self, train_file, valid_file, valid_num_ngs, eval_metric)
#     124             for batch_data_input in file_iterator:
#     125                 if batch_data_input:
# --> 126                     step_result = self.train(train_sess, batch_data_input)
#     127                     (_, _, step_loss, step_data_loss, summary) = step_result
#     128                     if self.hparams.write_tfevents and self.hparams.SUMMARIES_DIR:
#
# /content/Recommenders/reco_utils/recommender/deeprec/models/base_model.py in train(self, sess, feed_dict)
#     360                 self.merged,
#     361             ],
# --> 362             feed_dict=feed_dict,
#     363         )
#     364
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ###2.2 Evaluate model

# %%
res_syn = model.run_eval(test_file, num_ngs=test_num_ngs)
print(res_syn)
# Out:
# {'auc': 0.7161, 'logloss': 0.582, 'mean_mrr': 0.5172, 'ndcg@2': 0.4316, 'ndcg@4': 0.5234, 'ndcg@6': 0.587, 'group_auc': 0.7298}

# %%
sb.glue("res_syn", res_syn)

# %%
model = model.predict(train_file, output_file)

# %%
import pandas as pd
total_df = pd.read_csv(
        train_file,#'total_data.csv',
        sep="\t",
        names=["label", "user_id", "item_id", "timestamp", "cate_id" "hist_it", "hist_cat", "hist_ts", "hist"],
    )


pred_df = pd.read_csv(output_file,
                      sep="\t",
                      names=["pred"],
                      )
iff = total_df[["label","user_id", "item_id" ]]
iff["user_id"]= iff["user_id"].str[3:]
iff["item_id"]= iff["item_id"].str[3:]

oof = total_df[["user_id", "item_id" ]]
oof["user_id"]= oof["user_id"].str[3:]
oof["item_id"]= oof["item_id"].str[3:]
oof.insert(2,'pred', pred_df.values, True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# %cd recom-day-2020-challenge
import argmaxml
from functools import partial

# Fill in your full name, email and phone number
my_submit = partial(argmaxml.submit, "Karin", "karinboc@gmail.com", "052")
# %cd ..
# Out:
# /content/Recommenders/recom-day-2020-challenge
# /content/Recommenders

# %%
test_submission = oof.groupby("user_id")["item_id", "pred"]\
                    .apply(lambda x: list(x.groupby("item_id").max().idxmax())[0])
# test_submission = iff.groupby("user_id")["item_id", "label"]\
#                     .apply(lambda x: int(x.loc[x.label.idxmax()]['product_id'] ))             
test_submission
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# user_id
# 1        196
# 10       974
# 1000     774
# 1002    1412
# 1006    3334
#         ...
# 992     1270
# 993     2738
# 994      944
# 997     3030
# 999     1060
# Length: 2479, dtype: object

# %%
submission_name = "slirec_sub"
my_accuracy = my_submit(submission_name, test_submission)
print ("Submission Accuracy for {s} : {a:0.2f}%".format(a=100*my_accuracy, s=submission_name))
# Out:
# Submission Accuracy for slirec_sub : 12.19%

# %% [markdown]
# Online

# %%
model_best_trained = SeqModel(hparams, input_creator, seed=RANDOM_SEED)
path_best_trained = os.path.join(hparams.MODEL_DIR, "best_model")
print('loading saved model in {0}'.format(path_best_trained))
model_best_trained.load_model(path_best_trained)
# Out:
# loading saved model in ../../tests/resources/deeprec/caser/model/best_model

# %%
model_best_trained.run_eval(test_file, num_ngs=test_num_ngs)
# Out:
# {'auc': 0.7161,
#  'group_auc': 0.7298,
#  'logloss': 0.582,
#  'mean_mrr': 0.5172,
#  'ndcg@2': 0.4316,
#  'ndcg@4': 0.5234,
#  'ndcg@6': 0.587}

# %%
model_best_trained.predict(test_file, output_file)

# %%
with model_best_trained.sess as sess:
    graph_def = model_best_trained.graph.as_graph_def()
    output_graph_def = tf.graph_util.convert_variables_to_constants(
        sess,
        graph_def,
        ["pred"]
    )

    outfilepath = os.path.join(hparams.MODEL_DIR, "serving_model.pb")
    with tf.gfile.GFile(outfilepath, 'wb') as f:
        f.write(output_graph_def.SerializeToString())

# %%
class LoadFrozedPredModelCaser:
    def __init__(self, graph):
        self.pred = graph.get_tensor_by_name('import/pred:0') 
        self.items = graph.get_tensor_by_name('import/items:0') 
        self.cates = graph.get_tensor_by_name('import/cates:0') 
        self.item_history = graph.get_tensor_by_name('import/item_history:0') 
        self.item_cate_history = graph.get_tensor_by_name('import/item_cate_history:0') 
        # self.mask = graph.get_tensor_by_name('import/mask:0')  
        # self.time_from_first_action = graph.get_tensor_by_name('import/time_from_first_action:0') 
        # self.time_to_now = graph.get_tensor_by_name('import/time_to_now:0') 
        self.layer_keeps = graph.get_tensor_by_name('import/layer_keeps:0') 
        self.is_training = graph.get_tensor_by_name('import/is_training:0')

class LoadFrozedPredModel:
    def __init__(self, graph):
        self.pred = graph.get_tensor_by_name('import/pred:0') 
        self.items = graph.get_tensor_by_name('import/items:0') 
        self.cates = graph.get_tensor_by_name('import/cates:0') 
        self.item_history = graph.get_tensor_by_name('import/item_history:0') 
        self.item_cate_history = graph.get_tensor_by_name('import/item_cate_history:0') 
        # self.mask = graph.get_tensor_by_name('import/mask:0')  
        # self.time_from_first_action = graph.get_tensor_by_name('import/time_from_first_action:0') 
        # self.time_to_now = graph.get_tensor_by_name('import/time_to_now:0') 
        self.layer_keeps = graph.get_tensor_by_name('import/layer_keeps:0') 
        self.is_training = graph.get_tensor_by_name('import/is_training:0')

# %%
def infer_as_serving(model, infile, outfile, hparams, iterator, sess):
    preds = []
    
    for batch_data_input in iterator.load_data_from_file(infile, batch_num_ngs=0):
        if batch_data_input:
            feed_dict = {
                model.layer_keeps:np.ones(3, dtype=np.float32),
                model.is_training:False,
                model.items: batch_data_input[iterator.items],
                model.cates: batch_data_input[iterator.cates],
                model.item_history: batch_data_input[iterator.item_history],
                model.item_cate_history: batch_data_input[iterator.item_cate_history],
                # model.mask: batch_data_input[iterator.mask],
                # model.time_from_first_action: batch_data_input[iterator.time_from_first_action],
                # model.time_to_now: batch_data_input[iterator.time_to_now]
            }
            step_pred = sess.run(model.pred, feed_dict=feed_dict)
            #print(np.argmax(step_pred))
            print(feed_dict[model.items])
            preds.extend(np.reshape(step_pred, -1))
            
    print (len(preds))
    with open(outfile, "w") as wt:
        for line in preds:
            wt.write('{0}\n'.format(line))

# %%
G = tf.Graph()
with tf.gfile.GFile(
        os.path.join(hparams.MODEL_DIR, "serving_model.pb"),
        'rb'
) as f, G.as_default():
    graph_def_optimized = tf.GraphDef()
    graph_def_optimized.ParseFromString(f.read())
    
    ####  uncomment this line if you want to check what conent is included in the graph
    # print('graph_def_optimized = ' + str(graph_def_optimized))


with tf.Session(graph=G) as sess:
    tf.import_graph_def(graph_def_optimized)

    # print(sess.graph.get_tensor_by_name('import/mask:0'))
    # LoadFrozedPredModel(sess.graph)
    model = LoadFrozedPredModelCaser(sess.graph)
    
    serving_output_file = os.path.join(data_path, r'output_serving.txt')  
    iterator = input_creator(hparams, tf.Graph())
    infer_as_serving(model, test_file, serving_output_file, hparams, iterator, sess)
# Out:
# [ 5  2  1 11 18  4  7 16 17  9 22  1  3  5  2 23  9 16  4  6  6 15  3  2
#  20  9 14 10 13  5  9  1  2  6 11 16  3 12  5  8 39  1 11  8  9  2  5 28
#  27 32  2 11 12  3  6 20  9  4  1  5  3 17  2  1 16 28 20 13  5  4 17  6
#   2  3  1  5 19  4 11 16  3  6 10  9  1  5 14  8 22  7  2  3 11 17 14  1
#   7 13  6  8  6 24 10  3  1  2 21 25 23 11  2  5  1  3  4  6  9  7 11 22
#   2  8  1  5  3 28 17  6 14 30  2  1 23  3  8 18 15  4  5 20 12  7  1  2
#  23 14  5 22 13 18  2 17  3 16 11  8 21  9  1  5 17  1 15  2  7  4  9  3
#   6 12 23  2  3 11 12  8  1  6  5 22  1  3  5  2 11  4  6 12 16  9  6  5
#   2  1 18 11 13  9 24 10  2 18 17  4 21  1 10 15  5  3 17 18  8  1 21  2
#  11  3 14  5  9  5  2 31 15 36  1 28 12  8 21 17  2  1  7 19  4 41  3  5
#  25  5  6  2  1 16 27 17 12 10 21  2 22  3 10  1  5 17  6  4  2  1 21  4
#   6 20 13  9  3 27  1  9  3 16  2 18  5 11 17 22 11  2  1 17 16  9  3 31
#   8  5 17 37 21 20  5  1 16  2  8  4  1  2 12 14 13 10 20  4 16  5  1  5
#  16 23  9 33  6 25 10 17 12 18  1  5 29  4  6  2  8 16  1 12 20 25 21  6
#   9  8 15  7 17 13 31 16  9 21  1  5 20 10 17  5  2  1 19  3  6 18 21 12
#  38 40  2  4  5  1  6 15 21  7  4  1  2  6  9  5  8 12 16 11  2 31  1  4
#  12  6  9  5  3 21  3  2 11  1  5 15 16  7  6  4 20  5  2  1  9  8 11  4
#  18 26  1  6 11  5 13  3  2 17 10 20 17  1  7 21  4 11  2  5 12  6 40  1
#   9  4  3 24  7  2 15 17  2  3  1  9  5 21 17 14 28 12  2  1 11  5  8  4
#   7 15 10  6  2 11  1 23  6 31  5  3  4  7  1  9  2  3  5  7  4  8 10 21
#   7  5  9 23  1  6  4 14  3  2 32  6  2  1  3  5  4 17 13  9 17 14  3  2
#   1 20  6 18 19 32]
# 17470

# %%
# Out:
# <bound method Tensor.eval of <tf.Tensor 'import/pred:0' shape=(?, 1) dtype=float32>>

# %%
with tf.Session(graph=G) as sess:
  load_sess = sess
  preds = []
  labels = []
  group_preds = []
  group_labels = []
  group = test_num_ngs + 1

  for batch_data_input in iterator.load_data_from_file(
      test_file, min_seq_length=1, batch_num_ngs=0
  ):
      if batch_data_input:                 
          step_pred, step_labels = model_best_trained.infer(load_sess, batch_data_input)
          # preds.extend(np.reshape(step_pred, -1))
          # labels.extend(np.reshape(step_labels, -1))
          # group_preds.extend(np.reshape(step_pred, (-1, group)))
          # group_labels.extend(np.reshape(step_labels, (-1, group)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1119             subfeed_t = self.graph.as_graph_element(
# -> 1120                 subfeed, allow_tensor=True, allow_operation=False)
#    1121           except Exception as e:
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/ops.py in as_graph_element(self, obj, allow_tensor, allow_operation)
#    3606     with self._lock:
# -> 3607       return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#    3608
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/ops.py in _as_graph_element_locked(self, obj, allow_tensor, allow_operation)
#    3685       if obj.graph is not self:
# -> 3686         raise ValueError("Tensor %s is not an element of this graph." % obj)
#    3687       return obj
#
# ValueError: Tensor Tensor("label:0", shape=(?, 1), dtype=float32) is not an element of this graph.
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-275-b27acacecd1b> in <module>()
#      11   ):
#      12       if batch_data_input:
# ---> 13           step_pred, step_labels = model_best_trained.infer(load_sess, batch_data_input)
#      14           # preds.extend(np.reshape(step_pred, -1))
#      15           # labels.extend(np.reshape(step_labels, -1))
#
# /content/Recommenders/reco_utils/recommender/deeprec/models/base_model.py in infer(self, sess, feed_dict)
#     389         feed_dict[self.layer_keeps] = self.keep_prob_test
#     390         feed_dict[self.is_train_stage] = False
# --> 391         return sess.run([self.pred], feed_dict=feed_dict)
#     392
#     393     def load_model(self, model_path=None):
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1121           except Exception as e:
#    1122             raise TypeError('Cannot interpret feed_dict key as Tensor: ' +
# -> 1123                             e.args[0])
#    1124
#    1125           if isinstance(subfeed_val, ops.Tensor):
#
# TypeError: Cannot interpret feed_dict key as Tensor: Tensor Tensor("label:0", shape=(?, 1), dtype=float32) is not an element of this graph.
